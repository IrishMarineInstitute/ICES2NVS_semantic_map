# %% [markdown]
# # Import toolboxes

# %%
# Set display to width of screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Import toolboxes
import os
import numpy as np
import pandas as pd
import re
from SPARQLWrapper import SPARQLWrapper, JSON
from unidecode import unidecode
import urllib
import json
from pandas.io.json import json_normalize
import datetime

# Set Pandas DataFrame to resize to display full text
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Define functions used by the script

# %%
def xstr(s):
    """Function to remove non-ASCII characters from NVS results"""
    if s is None:
        return ''
    return str(unidecode(s))

def sparql_nvs_json(s):
    """Function to input a SPARQL query (s) into the NVS SPARQL endpoint"""
    sparql = SPARQLWrapper("http://vocab.nerc.ac.uk/sparql/sparql")
    sparql.setQuery(s)
    sparql.setReturnFormat(JSON)
    r = sparql.query().convert()
    return r

def S27_map():
    """Function to get NVS:S27 chemical substrances which have CAS numbers as a published mapping"""
    s =  """PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            PREFIX owl: <http://www.w3.org/2002/07/owl#>
                
            select ?codval ?prefLabel ?casurl
            where {
            <http://vocab.nerc.ac.uk/collection/S27/current/> skos:member ?url .
            # ?url skos:notation ?codval .
            # ?url skos:prefLabel ?prefLabel .
            # ?url owl:deprecated 'false' .
            # ?url owl:sameAs ?casurl .
            FILTER(regex(str(?casurl), "https://chem.nlm.nih.gov/chemidplus/rn/", "i"))
            }"""                
    r = sparql_nvs_json(s)    
    list = []
    for i in range(0,len(r['results']['bindings'])):
        a = xstr(r['results']['bindings'][i]['codval']['value'].replace('SDN:S27::',''))
        b = xstr(r['results']['bindings'][i]['prefLabel']['value'])
        c = xstr(r['results']['bindings'][i]['casurl']['value'].replace('http://chem.sis.nlm.nih.gov/chemidplus/rn/',''))
        list.append([a,b,c])
    return list

def taxon_map(spcs,aphia):
    """Function to get NVS:S25 TAXON from an AphiaID and species"""
    s =  """PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            PREFIX owl: <http://www.w3.org/2002/07/owl#>
                
            select ?prefLabel
            where {
                    <http://vocab.nerc.ac.uk/collection/S25/current/> skos:member ?url .
                    # ?url skos:notation ?codval .
                    # ?url skos:prefLabel ?prefLabel .
                    # ?url owl:deprecated 'false' .
                    FILTER(CONTAINS(?prefLabel,'%s')).
                    FILTER(CONTAINS(?prefLabel,'WoRMS %s)')).
                }""" % (spcs, aphia)
    r = sparql_nvs_json(s)
    list = []
    if len(r['results']['bindings']) == 0:
        a = 'Not available'
    else:
        label_list = []
        for i in range(0,len(r['results']['bindings'])):
            h = re.sub('\s\[.*?\]' ,'',xstr(r['results']['bindings'][i]['prefLabel']['value']))
            if h not in label_list:
                label_list.append(h)
                a = h
    list.append([a, aphia])
    return list

def S25_lookup(spcs,aphia,label):
    """Function to get NVS:S25 codval from the generated preflabel, if it exists"""
    s =  """PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            PREFIX owl: <http://www.w3.org/2002/07/owl#>
                
            select ?codval ?prefLabel
            where {
            <http://vocab.nerc.ac.uk/collection/S25/current/> skos:member ?url .
            # ?url skos:notation ?codval .
            # ?url skos:prefLabel ?prefLabel .
            # ?url owl:deprecated 'false' .
            FILTER(CONTAINS(?prefLabel,'%s (')).
            FILTER(CONTAINS(?prefLabel,'WoRMS %s')).
            FILTER(STRENDS(?prefLabel,'%s')).
            }""" % (spcs, aphia, label)
    r = sparql_nvs_json(s)
    list = []
    if len(r['results']['bindings']) == 0:
        a = 'No S25 term. Needs adding to NVS'
        b = "%s (ITIS: ?????: WoRMS %s) %s" % (spcs, aphia, label)
    else:
        for i in range(0,len(r['results']['bindings'])):
            a = xstr(r['results']['bindings'][i]['codval']['value'].replace('SDN:S25::',''))
            b = xstr(r['results']['bindings'][i]['prefLabel']['value'])
    list.append([a,b])
    return list

# %% [markdown]
# ##  Set input files, local mapping files and results directory for output

# %%
# Location of input file
inputfile = os.path.join(os.getcwd(),os.path.normpath('ICES2P01_test_dset.csv'))

# Filepaths for mapping files
mapfile = os.path.join(os.getcwd(),'mappings','unmapped_substances.csv')
biotamap = os.path.join(os.getcwd(),'mappings','biota_synonym_mapping.csv')
p02_file = os.path.join(os.getcwd(),'mappings','ICES2P02_mapping.csv')

# Set output file directory
results = os.path.join(os.getcwd(),'results')

# Set list to capture summary information for reporting at then end of the run
summary = []

# Set time run started
start = datetime.datetime.now()

# Add start time and holding space for end time to summary information
summary.append(["Processing started:" , (start.strftime('%Y-%m-%d %H:%M:%S'))]) 
summary.append(["Processing finished:" , ""])
summary.append(["" , ""])

# %% [markdown]
# ## Load ICES semantic model components for mapping to P01 semantic model from file into a Pandas DataFrame
#
# ### Example of expected input structure and headings
#
# <img align="left" style="padding-right:10px;" src="img/input_example.png"></br>

# %%
inputs = pd.read_csv(inputfile)
param_combo = inputs.copy(deep=True)

# Insert number of rows in the input file in to the summary information
print("Rows input: %s" % len(inputs))
summary.append(["Rows input:", len(inputs)])

# Make a working copy of the parameter combinations for mapping and remove duplicate combinations
param_combo = inputs.copy(deep=True).drop_duplicates(keep=False)
input_duplicates = len(inputs) - len(param_combo)
print("Rows duplicated: %s" % input_duplicates)
summary.append(["Rows duplicated:", input_duplicates])
summary.append(["" , ""])
print("Rows for mapping: %s" % len(param_combo))
summary.append(["Rows for mapping:", len(param_combo)])

# Add columns needed for P01 semantic model
# In the working copy set NaNs to '-9' and add columns for mapped NVS semantic model elements
param_combo = param_combo.fillna('-9')
param_combo = param_combo.assign(S06_label='',              # Measurement Property
                                 S07_label='not specified', # Measurement Property Statistic
                                 S02_label='',              # Measurement - Matrix relationship
                                 )
param_combo['PARAM'] = param_combo['PARAM'].str.upper()
param_combo['AphiaID'] = param_combo['AphiaID'].astype('int32')
# Remove leading or trailing spaces from the text columns
columns = param_combo.columns.tolist()
columns.remove('AphiaID')
for column in columns:
    param_combo[column] = param_combo[column].str.strip()
# Out:
# Rows input: 5439
# Rows duplicated: 44
# Rows for mapping: 5395

# %% [markdown]
# ### Display sample of sediment ICES parameter combinations

# %%
display(param_combo[param_combo['DTYPE']=='CS'][['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note']].head(10))
# Out:
#                                           PRNAM         CAS DTYPE  PARAM  \
# 0  anthracene                                    120-12-7    CS    ANT
# 1  benzo[a]pyrene                                50-32-8     CS    BAP
# 2  2,2',4,5,5'-pentachlorobiphenyl (CB101)       37680-73-2  CS    CB101
# 3  2,3,3',4,4'-pentachlorobiphenyl (CB105)       32598-14-4  CS    CB105
# 4  2,3',4,4',5-pentachlorobiphenyl (CB118)       31508-00-6  CS    CB118
# 5  2,2',3,4,4',5'-hexachlorobiphenyl (CB138)     35065-28-2  CS    CB138
# 6  2,2',4,4',5,5'-hexachlorobiphenyl (CB153)     35065-27-1  CS    CB153
# 7  2,2',3,4,4',5,5'-heptachlorobiphenyl (CB180)  35065-29-3  CS    CB180
# 8  2,4,4'-trichlorobiphenyl (CB28)               7012-37-5   CS    CB28
# 9  2,2',5,5'-tetrachlorobiphenyl (CB52)          35693-99-3  CS    CB52
#
#    MUNIT    MATRX BASIS METPT METOA Species  AphiaID Note
# 0  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 1  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 2  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 3  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 4  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 5  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 6  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 7  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 8  ug/kg  SED1000  D     -9    -9    -9     -9        -9
# 9  ug/kg  SED1000  D     -9    -9    -9     -9        -9

# %% [markdown]
# ### Display sample of water ICES parameter combinations

# %%
display(param_combo[param_combo['DTYPE']=='CW'][['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note']].head(10))
# Out:
#                                                 PRNAM          CAS DTYPE  \
# 461  anthracene                                        120-12-7     CW
# 462  benzo[a]pyrene                                    50-32-8      CW
# 463  2,2',4,4',6-pentabromodiphenyl ether (PBDE100)    189084-64-8  CW
# 464  2,2',4,4',5,5'-hexabromodiphenyl ether (PBDE153)  68631-49-2   CW
# 465  2,2',4,4',5,6'-hexabromodiphenyl ether (PBDE154)  207122-15-4  CW
# 466  2,4,4'-tribromodiphenyl ether (PBDE28)            41318-75-6   CW
# 467  2,2',4,4'-tetrabromodiphenyl ether (PBDE47)       5436-43-1    CW
# 468  2,2',4,4',5-pentabromodiphenyl ether (PBDE99)     60348-60-9   CW
# 469  cadmium                                           7440-43-9    CW
# 470  cadmium                                           7440-43-9    CW
#
#      PARAM  MUNIT MATRX BASIS      METPT METOA Species  AphiaID Note
# 461  ANT    ug/g   SPM   D     NONE       -9    -9     -9        -9
# 462  BAP    ug/g   SPM   D     NONE       -9    -9     -9        -9
# 463  BD100  ug/g   SPM   D     NONE       -9    -9     -9        -9
# 464  BD153  ug/g   SPM   D     NONE       -9    -9     -9        -9
# 465  BD154  ug/g   SPM   D     NONE       -9    -9     -9        -9
# 466  BDE28  ug/g   SPM   D     NONE       -9    -9     -9        -9
# 467  BDE47  ug/g   SPM   D     NONE       -9    -9     -9        -9
# 468  BDE99  ug/g   SPM   D     NONE       -9    -9     -9        -9
# 469  CD     ug/g   SPM   -9    FM-PC-0.4  -9    -9     -9        -9
# 470  CD     ug/kg  SPM   W     NF         -9    -9     -9        -9

# %% [markdown]
# ### Display sample of biota ICES parameter combinations

# %%
display(param_combo[param_combo['DTYPE']=='CF'][['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note']].head(10))
# Out:
#                                    PRNAM         CAS DTYPE  PARAM MUNIT MATRX  \
# 792  Benzene, 1-bromo-2-phenoxy- (PBDE1)  7025-06-01  CF    BDE1   -9    SB
# 793  Benzene, 1-bromo-4-phenoxy-          101-55-3    CF    BDE3   -9    SB
# 794  cis-heptachlorepoxide "(alpha)"      1024-57-3   CF    HCEPC  -9    SB
# 795  cis-heptachlorepoxide "(alpha)"      1024-57-3   CF    HCEPC  -9    SB
# 796  cis-heptachlorepoxide "(alpha)"      1024-57-3   CF    HCEPC  -9    SB
# 797  cis-heptachlorepoxide "(alpha)"      1024-57-3   CF    HCEPC  -9    SB
# 798  cis-heptachlorepoxide "(alpha)"      1024-57-3   CF    HCEPC  -9    SB
# 799  cis-heptachlorepoxide "(alpha)"      1024-57-3   CF    HCEPC  -9    SB
# 800  endosulfan sulfate                   1031-07-8   CF    ENDS   -9    SB
# 801  endosulfan sulfate                   1031-07-8   CF    ENDS   -9    MU
#
#     BASIS METPT METOA                  Species  AphiaID        Note
# 792  W     -9    -9    Mytilus edulis           140480   Mollusca
# 793  W     -9    -9    Mytilus edulis           140480   Mollusca
# 794  W     -9    -9    Ostrea edulis            140658   Mollusca
# 795  W     -9    -9    Venerupis philippinarum  231750   Mollusca
# 796  W     -9    -9    Cerastoderma edule       138998   Mollusca
# 797  W     -9    -9    Crassostrea gigas        140656   Mollusca
# 798  W     -9    -9    Ensis siliqua            140735   Mollusca
# 799  W     -9    -9    Mytilus edulis           140480   Mollusca
# 800  W     -9    -9    Ostrea edulis            140658   Mollusca
# 801  W     -9    -9    Palaemon serratus        107616   Crustacean

# %% [markdown]
# ### Display sample of P01 parameter codes and semantic model components

# %% [markdown]
# ## Load P01 terms and semantic model vocabularies from the NERC Vocabulary Server
#
# ### For more details of the P01 Parameter Usage Vocabulary and the underlying semantic model please see the IMDIS 2018 presentation:
# #### Slides: https://www.bodc.ac.uk/about/outputs/presentations_and_papers/documents/imdis2018gmon_alexk.pdf
# #### Video: https://www.youtube.com/watch?v=ePFqUSsteQs

# %%
#%% Get the latest semantic model vocabulary contents from the NVS Sparql endpoint

a1 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0A++++PREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A++++%0D%0A++++select+%3F"
a2 = "+%3F"
a3 = "%0D%0A++++where+%7B%0D%0A++++%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2F"
a4 = "%2Fcurrent%2F%3E+skos%3Amember+%3Furl+.%0D%0A++++%3Furl+skos%3AprefLabel+%3F"
a5 = "+.%0D%0A++++%3Furl+skos%3Anotation+%3Fc+.%0D%0A++++%3Furl+owl%3Adeprecated+%27false%27+.%0D%0A++++BIND%28replace%28str%28%3Fc%29%2C%27SDN%3A"
a6 = "%3A%3A%27%2C%27%27%2C%27i%27%29+AS+%3F"
a7 = "%29%0D%0A++++%7D&output=csv&stylesheet="

S06 = pd.read_csv(a1+'S06'+a2+'S06_label'+a3+'S06'+a4+'S06_label'+a5+'S06'+a6+'S06'+a7)
S07 = pd.read_csv(a1+'S07'+a2+'S07_label'+a3+'S07'+a4+'S07_label'+a5+'S07'+a6+'S07'+a7)
S02 = pd.read_csv(a1+'S02'+a2+'S02_label'+a3+'S02'+a4+'S02_label'+a5+'S02'+a6+'S02'+a7)
S26 = pd.read_csv(a1+'S26'+a2+'S26_label'+a3+'S26'+a4+'S26_label'+a5+'S26'+a6+'S26'+a7)
S03 = pd.read_csv(a1+'S03'+a2+'S03_label'+a3+'S03'+a4+'S03_label'+a5+'S03'+a6+'S03'+a7)
S04 = pd.read_csv(a1+'S04'+a2+'S04_label'+a3+'S04'+a4+'S04_label'+a5+'S04'+a6+'S04'+a7)
S05 = pd.read_csv(a1+'S05'+a2+'S05_label'+a3+'S05'+a4+'S05_label'+a5+'S05'+a6+'S05'+a7)
P01 = pd.read_csv(a1+'P01'+a2+'P01_label'+a3+'P01'+a4+'P01_label'+a5+'P01'+a6+'P01'+a7)

# Download semantic component mapping

urlS06 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS06+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS06%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Anarrower+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS06%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS06%29+.%0D%0A%7D&output=csv&stylesheet="
S06_P01 = pd.read_csv(urlS06)
print("P01-S06 mapping downloaded.")

urlS07 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS07+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS07%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Anarrower+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS07%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS07%29+.%0D%0A%7D&output=csv&stylesheet="
S07_P01 = pd.read_csv(urlS07)
print("P01-S07 mapping downloaded.")

urlS27 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS27+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS27%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Anarrower+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS27%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS27%29+.%0D%0A%7D&output=csv&stylesheet="
S27_P01 = pd.read_csv(urlS27)
print("P01-S27 mapping downloaded.")

urlS02 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS02+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS02%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS02%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS02%29+.%0D%0A%7D&output=csv&stylesheet="
S02_P01 = pd.read_csv(urlS02)
print("P01-S02 mapping downloaded.")

urlS26 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS26+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS26%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Anarrower+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS26%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS26%29+.%0D%0A%7D&output=csv&stylesheet="
S26_P01 = pd.read_csv(urlS26)
print("P01-S26 mapping downloaded.")

urlS25 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS25+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Anarrower+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0A%7D&output=csv&stylesheet="
S25_P01 = pd.read_csv(urlS25)
print("P01-S25 mapping downloaded.")

urlS03 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS03+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS03%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS03%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS03%29+.%0D%0A%7D&output=csv&stylesheet="
S03_P01 = pd.read_csv(urlS03)
print("P01-S03 mapping downloaded.")

urlS04 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS04+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS04%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS04%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS04%29+.%0D%0A%7D&output=csv&stylesheet="
S04_P01 = pd.read_csv(urlS04)
print("P01-S04 mapping downloaded.")

urlS05 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS05+%3FP01%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS05%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FP01%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AP01%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FP01%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS05%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS05%29+.%0D%0A%7D&output=csv&stylesheet="
S05_P01 = pd.read_csv(urlS05)
print("P01-S05 mapping downloaded.")

# Build P01 semantic model dataframe
P01 = pd.merge(P01, S06_P01, how='left', on='P01')
P01 = pd.merge(P01, S07_P01, how='left', on='P01')
P01 = pd.merge(P01, S27_P01, how='left', on='P01')
P01 = pd.merge(P01, S02_P01, how='left', on='P01')
P01 = pd.merge(P01, S26_P01, how='left', on='P01')
P01 = pd.merge(P01, S25_P01, how='left', on='P01')
P01 = pd.merge(P01, S03_P01, how='left', on='P01')
P01 = pd.merge(P01, S04_P01, how='left', on='P01')
P01 = pd.merge(P01, S05_P01, how='left', on='P01')

P01 = P01.fillna(value={'S25': 'BE007736', 'S07': 'S0700006', 'S03': 'S0316', 'S04': 'S0421', 'S05': 'S050003'})

print("P01 semantic model dataframe constructed")
# Out:
# P01-S06 mapping downloaded.
# P01-S07 mapping downloaded.
# P01-S27 mapping downloaded.
# P01-S02 mapping downloaded.
# P01-S26 mapping downloaded.
# P01-S25 mapping downloaded.
# P01-S03 mapping downloaded.
# P01-S04 mapping downloaded.
# P01-S05 mapping downloaded.
# P01 semantic model dataframe constructed

# %%
display(P01[P01['P01_label'].str.contains('copper')].head(10))
# Out:
#            P01  \
# 186   CF223WPP
# 5638  IFRMET18
# 7051  CUCNSTXT
# 7052  MCUSP012
# 7107  CUSEDBD1
# 7275  CUTDICP5
# 7276  CUXXZZZZ
# 7277  CF002DME
# 7278  XMETAL16
# 7279  XMETAL23
#
#                                                                                                                                                                                                 P01_label  \
# 186   Concentration of copper {Cu CAS 7440-50-8} per unit wet weight of biota {Pleuronectes platessa (ITIS: 172902: WoRMS 127143) [Sex: male Subcomponent: muscle tissue]}
# 5638  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of biota {Crassostrea rhizophorae (ITIS: 79881: WoRMS 420777) [Subcomponent: flesh]}
# 7051  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of sediment by acid digestion of leached sample residue and atomic absorption spectroscopy and summation of staged leachate analyses
# 7052  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of sediment
# 7107  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of sediment <2000um
# 7275  Concentration of copper {Cu CAS 7440-50-8} per unit volume of the water body [dissolved plus reactive particulate phase] by acidification and inductively-coupled plasma mass spectrometry
# 7276  Concentration of copper {Cu CAS 7440-50-8} per unit volume of the water body [dissolved plus reactive particulate phase]
# 7277  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of biota {Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]}
# 7278  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of biota {Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]} by graphite furnace atomic absorption spectroscopy
# 7279  Concentration of copper {Cu CAS 7440-50-8} per unit dry weight of biota {Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]} by inductively-coupled plasma mass spectrometry
#
#            S06       S07       S27   S02       S26       S25     S03     S04  \
# 186   S0600045  S0700006  CS002454  S055  MAT01963  BE006659  S0316   S0421
# 5638  S0600045  S0700006  CS002454  S041  MAT01963  BE007120  S0316   S0421
# 7051  S0600045  S0700006  CS002454  S041  MAT00136  BE007736  S03465  S04119
# 7052  S0600045  S0700006  CS002454  S041  MAT00136  BE007736  S0316   S0421
# 7107  S0600045  S0700006  CS002454  S041  MAT00080  BE007736  S0316   S0421
# 7275  S0600045  S0700006  CS002454  S053  MAT00633  BE007736  S0366   S04236
# 7276  S0600045  S0700006  CS002454  S053  MAT00633  BE007736  S0316   S0421
# 7277  S0600045  S0700006  CS002454  S041  MAT01963  BE006336  S0316   S0421
# 7278  S0600045  S0700006  CS002454  S041  MAT01963  BE006336  S0316   S04196
# 7279  S0600045  S0700006  CS002454  S041  MAT01963  BE006336  S0316   S04236
#
#           S05
# 186   S050003
# 5638  S050003
# 7051  S050165
# 7052  S050003
# 7107  S050003
# 7275  S050003
# 7276  S050003
# 7277  S050003
# 7278  S050003
# 7279  S050003

# %% [markdown]
# # Mapping of chemical PARAMs and NVS S27 vocabulary entries
# ### Determine where direct mappings already published on the NVS

# %%
# First get S27 terms that have a mapping to ICES PARAM vocabulary published from the NVS
q = """PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
                    
    select ?PARAM ?S27 ?S27_label 
    where {
           <http://vocab.nerc.ac.uk/collection/S27/current/> skos:member ?url .
           # ?url skos:notation ?a .
           # ?url skos:prefLabel ?S27_label .
           # ?url owl:deprecated 'false' .
           # ?url skos:related ?c .
           FILTER(regex(str(?c), "http://vocab.ices.dk/services/rdf/collection/PARAM/", "i")) .
           BIND(substr(?a,10,8) as ?S27) .
           BIND(replace(str(?c), "http://vocab.ices.dk/services/rdf/collection/PARAM/", "", "i") AS ?PARAM) .
          }"""
# URL for the above query is:
url = """http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0A++++PREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A++++++++++++++++++++%0D%0A++++select+%3FPARAM+%3FS27+%3FS27_label+%0D%0A++++where+%7B%0D%0A+++++++++++%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS27%2Fcurrent%2F%3E+skos%3Amember+%3Furl+.%0D%0A+++++++++++%3Furl+skos%3Anotation+%3Fa+.%0D%0A+++++++++++%3Furl+skos%3AprefLabel+%3FS27_label+.%0D%0A+++++++++++%3Furl+owl%3Adeprecated+%27false%27+.%0D%0A+++++++++++%3Furl+skos%3Arelated+%3Fc+.%0D%0A+++++++++++FILTER%28regex%28str%28%3Fc%29%2C+%22http%3A%2F%2Fvocab.ices.dk%2Fservices%2Frdf%2Fcollection%2FPARAM%2F%22%2C+%22i%22%29%29+.%0D%0A+++++++++++BIND%28substr%28%3Fa%2C10%2C8%29+as+%3FS27%29+.%0D%0A+++++++++++BIND%28replace%28str%28%3Fc%29%2C+%22http%3A%2F%2Fvocab.ices.dk%2Fservices%2Frdf%2Fcollection%2FPARAM%2F%22%2C+%22%22%2C+%22i%22%29+AS+%3FPARAM%29+.%0D%0A++++++++++%7D&output=CSV&stylesheet="""

# More efficient to ingest SPARQL response as a CSV directly into a Pandas DataFrame
mapped_chems = pd.read_csv(url)
mapped_chems['SOURCE'] = 'NVS'

print("Number of ICES PARAM terms directly mapped to S27 chemical substance terms from NVS: %s" % (len(mapped_chems)))
summary.append(["Number of ICES PARAM terms directly mapped to S27 chemical substance terms from NVS:", (len(mapped_chems))])

display(mapped_chems)
# Out:
# Number of ICES PARAM terms directly mapped to S27 chemical substance terms from NVS: 0
# Empty DataFrame
# Columns: [PARAM, S27, S27_label, SOURCE]
# Index: []

# %% [markdown]
# ### Get local ICES PARAM to NVS S27 substance mapping from mapping file location provided earlier

# %%
local_map = pd.read_csv(mapfile)
local_map['SOURCE'] = mapfile

print("Number of local mappings for chemical substances from file: %s" % (len(local_map)))
summary.append(["Number of local mappings for chemical substances from file:" , (len(local_map))])

display(local_map)
# Out:
# Number of local mappings for chemical substances from file: 46
#      PARAM                                              PRNAM   ICES_CASRN  \
# 0   24D     2,4-dichlorophenoxyacetic acid                     94-75-7
# 1   ATRZ    atrazine                                           1912-24-9
# 2   BD190   2,3,3',4,4',5,6-heptabromodiphenyl ether (BDE190)  189084-68-2
# 3   BENZ    benzene                                            71-43-2
# 4   CACO3   calcium carbonate                                  471-34-1
# 5   CB137   2,2',3,4,4',5-hexachlorobiphenyl (CB137)           35694-06-5
# 6   CB56    2,3,3',4'-tetrachlorobiphenyl (CB56)               41464-43-1
# 7   CB85    2,2',3,4,4'-pentachlorobiphenyl (CB85)             65510-45-4
# 8   CB97    2,2',3',4,5-pentachlorobiphenyl (CB97)             41464-51-1
# 9   CO      cobalt                                             7440-48-4
# 10  CORG    organic carbon                                     NaN
# 11  CS137   cesium-137                                         NaN
# 12  CTOT    total carbon                                       NaN
# 13  DBTIN   dibutyltin (DBT) - expressed as Sn-atom            GM
# 14  DCE     1,2-dichloroethane                                 107-06-2
# 15  DCM     Dichloromethane                                    75-09-2
# 16  DEHP    Phthalic acid, bis(2-ethylhexyl) ester             117-81-7
# 17  DIC     dissolved inorganic carbon                         NaN
# 18  DIURN   Diuron                                             330-54-1
# 19  DPTIN   diphenyltin - expressed as Sn-atom                 GM
# 20  GLYPH   glyphosate                                         1071-83-6
# 21  LINRN   linuron                                            330-55-2
# 22  MBTIN   monobutyltin (MBT) - expressed as Sn-atom          GM
# 23  MCPA    Acetic acid, (4-chloro-2-methylphenoxy)-           94-74-6
# 24  MCPP    Mecoprop                                           93-65-2
# 25  MN      manganese                                          7439-96-5
# 26  MPTIN   monophenyltin - expressed as Sn-atom               GM
# 27  NOPHE   Nonylphenols                                       25154-52-3
# 28  NOPHE4  4-Nonylphenol                                      104-40-5
# 29  NORG    organic nitrogen (N)                               NaN
# 30  NP1EO   nonylphenolmonoethoxylates                         GM
# 31  NP2EO   nonylphenoldiethoxylates                           GM
# 32  OCPHE4  4-Octylphenol                                      1806-26-4
# 33  PHATA   phaeophytin-a                                      603-17-8
# 34  SIMZ    simazine                                           122-34-9
# 35  TETIN   tetrabutyltin - expressed as Sn-atom               1461-25-2
# 36  TOL     toluene                                            108-88-3
# 37  TRCB    1,2,4-trichlorobenzene                             120-82-1
# 38  TRCB1   1,2,3-trichlorobenzene                             87-61-6
# 39  TRCB2   1,3,5-trichlorobenzene                             108-70-3
# 40  TRCBM1  1,2,3/1,2,4/1,3,5 trichlorobenzene mixture         GM
# 41  U       uranium                                            7440-61-1
# 42  V       vanadium                                           7440-62-2
# 43  XYL     xylene                                             1330-20-7
# 44  XYLMP   m- & p-xylene                                      GM
# 45  XYLO    NaN                                                95-47-6
#
#                                       S27_label       S27    NVS_CASRN  \
# 0   2,4-dichlorophenoxyacetic acid               CS001551  94-75-7
# 1   atrazine                                     CS001579  1912-24-9
# 2   2,3,3',4,4',5,6-heptabromodiphenyl ether     CS002181  189084-68-2
# 3   benzene                                      CS003272  71-43-2
# 4   calcium carbonate                            CS003129  471-34-1
# 5   2,2',3,4,4',5-hexachlorobiphenyl             CS001740  35694-06-5
# 6   2,3,3',4'-tetrachlorobiphenyl                CS001852  41464-43-1
# 7   2,2',3,4,4'-pentachlorobiphenyl              CS001747  65510-45-4
# 8   2,2',3,4',5'-pentachlorobiphenyl             CS001691  41464-51-1
# 9   cobalt                                       CS002447  7440-48-4
# 10  organic carbon                               CS002857  NaN
# 11  caesium-137                                  CS002370  NaN
# 12  total carbon                                 CS002860  NaN
# 13  dibutyltin (expressed as tin)                CS003620  NaN
# 14  1,2-dichloroethane                           CS003247  107-06-2
# 15  dichloromethane                              CS003270  75-09-2
# 16  bis(2-ethylhexyl)phthalate                   CS001194  117-81-7
# 17  total inorganic carbon                       CS002894  NaN
# 18  diuron                                       CS003293  330-54-1
# 19  diphenyltin (expressed as tin)               CS003626  NaN
# 20  N-(phosphonomethyl)glycine                   CS003617  1071-83-6
# 21  linuron                                      CS000697  330-55-2
# 22  monobutyltin (expressed as tin)              CS003621  NaN
# 23  4-chloro-2-methylphenoxyacetic acid          CS001145  94-74-6
# 24  methylchlorophenoxypropionic acid            CS000718  93-65-2
# 25  total manganese                              CS000305  7439-96-5
# 26  monophenyltin (expressed as tin)             CS003627  NaN
# 27  nonylphenol                                  CS003674  NaN
# 28  4-nonylphenol                                CS003211  NaN
# 29  organic nitrogen                             CS002859  NaN
# 30  nonylphenol monoethoxylate                   CS003631  NaN
# 31  nonylphenol diethoxylate                     CS003632  NaN
# 32  4-octylphenol                                CS003619  1806-26-4
# 33  phaeophytin-a                                CS002998  603-17-8
# 34  simazine                                     CS000837  122-34-9
# 35  tetrabutyltin (expressed as tin)             CS003622  1461-25-2
# 36  methylbenzene                                CS003183  108-88-3
# 37  1,2,4-trichlorobenzene                       CS000956  120-82-1
# 38  1,2,3-trichlorobenzene                       CS000949  87-61-6
# 39  1,3,5-trichlorobenzene                       CS000970  108-70-3
# 40  trichlorobenzenes                            CS003383  12002-48-1
# 41  uranium                                      CS026907  7440-61-1
# 42  vanadium                                     CS002664  7440-62-2
# 43  xylene                                       CS003384  1330-20-7
# 44  1,3-dimethylbenzene and 1,4-dimethylbenzene  CS003482  NaN
# 45  1,2-dimethylbenzene                          CS000963  95-47-6
#
#                                                                                                   SOURCE
# 0   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 1   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 2   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 3   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 4   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 5   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 6   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 7   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 8   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 9   C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 10  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 11  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 12  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 13  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 14  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 15  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 16  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 17  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 18  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 19  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 20  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 21  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 22  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 23  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 24  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 25  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 26  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 27  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 28  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 29  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 30  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 31  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 32  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 33  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 34  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 35  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 36  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 37  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 38  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 39  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 40  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 41  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 42  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 43  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 44  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 45  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv

# %% [markdown]
# ### Identify any mappings in the local file also published from the NVS

# %%
duplicate_map = pd.merge(mapped_chems, local_map, how='inner', on='PARAM')

print("Number of chemical substance mappings in both local file and NVS: %s" % (len(duplicate_map)))
summary.append(["Number of chemical substance mappings in both local file and NVS:" , (len(duplicate_map))])

display(duplicate_map)
# Out:
# Number of chemical substance mappings in both local file and NVS: 0
# Empty DataFrame
# Columns: [S27_x, S27_label_x, SOURCE_x, PARAM, PRNAM, ICES_CASRN, S27_label_y, S27_y, NVS_CASRN, SOURCE_y]
# Index: []

# %% [markdown]
# ### Display local mappings, where CAS RN do not match between NVS and ICES or are absent, for review with BODC vocab team (vocab.services@bodc.ac.uk) for upload to NVS

# %%
display(local_map[local_map['ICES_CASRN']!=local_map['NVS_CASRN']])
# Out:
#      PARAM                                       PRNAM  ICES_CASRN  \
# 10  CORG    organic carbon                              NaN
# 11  CS137   cesium-137                                  NaN
# 12  CTOT    total carbon                                NaN
# 13  DBTIN   dibutyltin (DBT) - expressed as Sn-atom     GM
# 17  DIC     dissolved inorganic carbon                  NaN
# 19  DPTIN   diphenyltin - expressed as Sn-atom          GM
# 22  MBTIN   monobutyltin (MBT) - expressed as Sn-atom   GM
# 26  MPTIN   monophenyltin - expressed as Sn-atom        GM
# 27  NOPHE   Nonylphenols                                25154-52-3
# 28  NOPHE4  4-Nonylphenol                               104-40-5
# 29  NORG    organic nitrogen (N)                        NaN
# 30  NP1EO   nonylphenolmonoethoxylates                  GM
# 31  NP2EO   nonylphenoldiethoxylates                    GM
# 33  PHATA   phaeophytin-a                               603-17-8
# 40  TRCBM1  1,2,3/1,2,4/1,3,5 trichlorobenzene mixture  GM
# 44  XYLMP   m- & p-xylene                               GM
#
#                                       S27_label       S27   NVS_CASRN  \
# 10  organic carbon                               CS002857  NaN
# 11  caesium-137                                  CS002370  NaN
# 12  total carbon                                 CS002860  NaN
# 13  dibutyltin (expressed as tin)                CS003620  NaN
# 17  total inorganic carbon                       CS002894  NaN
# 19  diphenyltin (expressed as tin)               CS003626  NaN
# 22  monobutyltin (expressed as tin)              CS003621  NaN
# 26  monophenyltin (expressed as tin)             CS003627  NaN
# 27  nonylphenol                                  CS003674  NaN
# 28  4-nonylphenol                                CS003211  NaN
# 29  organic nitrogen                             CS002859  NaN
# 30  nonylphenol monoethoxylate                   CS003631  NaN
# 31  nonylphenol diethoxylate                     CS003632  NaN
# 33  phaeophytin-a                                CS002998  603-17-8
# 40  trichlorobenzenes                            CS003383  12002-48-1
# 44  1,3-dimethylbenzene and 1,4-dimethylbenzene  CS003482  NaN
#
#                                                                                                   SOURCE
# 10  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 11  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 12  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 13  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 17  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 19  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 22  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 26  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 27  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 28  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 29  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 30  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 31  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 33  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 40  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv
# 44  C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\mappings\unmapped_substances.csv

# %% [markdown]
# ### For unmapped chemical PARAMs with CAS numbers, check if the chemical substance exists within S27 and then map via CAS number

# %%
# SPARQL query for all NVS substances with CAS numbers from the SPARQL endpoint
q =  """PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
            
    select ?nvs_codval ?nvs_prefLabel ?nvs_casrn
    where {
           <http://vocab.nerc.ac.uk/collection/S27/current/> skos:member ?url .
           # ?url skos:notation ?a .
           # ?url skos:prefLabel ?nvs_prefLabel .
           # ?url owl:deprecated 'false' .
           # ?url owl:sameAs ?c .
           FILTER(regex(str(?c), "https://chem.nlm.nih.gov/chemidplus/rn/", "i")) .
           BIND(replace(str(?a),'SDN:S27::','','i') AS ?nvs_codval) .
           BIND(replace(str(?c),'https://chem.nlm.nih.gov/chemidplus/rn/','','i') AS ?nvs_casrn) .
          }"""                

# URL for the above query is:
url = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX%20skos%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0APREFIX%20owl%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0A%0Aselect%20%3Fnvs_codval%20%3Fnvs_prefLabel%20%3Fnvs_casrn%0Awhere%20%7B%0A%20%20%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS27%2Fcurrent%2F%3E%20skos%3Amember%20%3Furl%20.%0A%20%20%3Furl%20skos%3Anotation%20%3Fa%20.%0A%20%20%3Furl%20skos%3AprefLabel%20%3Fnvs_prefLabel%20.%0A%20%20%3Furl%20owl%3Adeprecated%20'false'%20.%0A%20%20%3Furl%20owl%3AsameAs%20%3Fc%20.%0A%20%20FILTER(regex(str(%3Fc)%2C'https%3A%2F%2Fchem.nlm.nih.gov%2Fchemidplus%2Frn%2F'%2C'i'))%20.%0A%20%20BIND(replace(str(%3Fa)%2C'SDN%3AS27%3A%3A'%2C''%2C'i')%20AS%20%3Fnvs_codval)%20.%0A%20%20BIND(replace(str(%3Fc)%2C'https%3A%2F%2Fchem.nlm.nih.gov%2Fchemidplus%2Frn%2F'%2C''%2C'i')%20AS%20%3Fnvs_casrn)%20.%0A%7D&output=csv&stylesheet="   

# More efficient to ingest SPARQL response as a CSV directly into a Pandas DataFrame
nvs_cas = pd.read_csv(url)

print("Number of chemical substances in S27 with a CAS number: %s" % len(nvs_cas))
# Out:
# Number of chemical substances in S27 with a CAS number: 1130

# %% [markdown]
# ### Combine NVS mappings and local file then apply mapping to input file

# %%
cas_map = nvs_cas.drop_duplicates(subset=['nvs_casrn'], keep=False).rename(columns={"nvs_codval": "S27", "nvs_prefLabel": "S27_label", "nvs_casrn": "CAS"})
cas_map['SOURCE']='CASRN'

# Remove duplicate records for as CASRN from the NVS and concatenate all remaining mappings giving precidence to the local mappings where there is duplication
full_chem_map = pd.concat([mapped_chems,
                           local_map[['PARAM','S27','S27_label','SOURCE']], 
                           pd.merge(param_combo[(param_combo['CAS']!=-9)][['PARAM','CAS']],cas_map,how='inner', on='CAS').drop_duplicates()],
                          sort=True                          
                         ).drop_duplicates(subset='PARAM', keep='first').reset_index(drop=True)

# Add S27 semantic model mapping to the main table based on the combinations provided   
param_combo = pd.merge(param_combo, full_chem_map.drop(columns=['CAS']), how='left', on=['PARAM'])

print("Rows mapped from NVS and local mapping of chemical substance: %s" % len(param_combo[param_combo['S27'].notnull()]))
# Out:
# Rows mapped from NVS and local mapping of chemical substance: 3965

# %% [markdown]
# ### Display mapping progress

# %%
display(param_combo[['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note','S06_label','S07_label','S27_label']])
# Out:
#                                                         PRNAM         CAS  \
# 0     anthracene                                               120-12-7
# 1     benzo[a]pyrene                                           50-32-8
# 2     2,2',4,5,5'-pentachlorobiphenyl (CB101)                  37680-73-2
# 3     2,3,3',4,4'-pentachlorobiphenyl (CB105)                  32598-14-4
# 4     2,3',4,4',5-pentachlorobiphenyl (CB118)                  31508-00-6
# 5     2,2',3,4,4',5'-hexachlorobiphenyl (CB138)                35065-28-2
# 6     2,2',4,4',5,5'-hexachlorobiphenyl (CB153)                35065-27-1
# 7     2,2',3,4,4',5,5'-heptachlorobiphenyl (CB180)             35065-29-3
# 8     2,4,4'-trichlorobiphenyl (CB28)                          7012-37-5
# 9     2,2',5,5'-tetrachlorobiphenyl (CB52)                     35693-99-3
# 10    cadmium                                                  7440-43-9
# 11    copper                                                   7440-50-8
# 12    DDE (p,p')                                               72-55-9
# 13    DDT (o,p')                                               789-02-6
# 14    DDT (p,p')                                               50-29-3
# 15    fluoranthene                                             206-44-0
# 16    hexachlorobenzene                                        118-74-1
# 17    mercury                                                  7439-97-6
# 18    naphthalene                                              91-20-3
# 19    phenanthrene                                             85-01-8
# 20    lead                                                     7439-92-1
# 21    TDE (p,p') = DDD (p,p')                                  72-54-8
# 22    zinc                                                     7440-66-6
# 23    aluminium                                                7429-90-5
# 24    aluminium                                                7429-90-5
# 25    aluminium                                                7429-90-5
# 26    aluminium                                                7429-90-5
# 27    anthracene                                               120-12-7
# 28    benzo[a]pyrene                                           50-32-8
# 29    2,2',4,5,5'-pentachlorobiphenyl (CB101)                  37680-73-2
# ...                                       ...                         ...
# 5365  length (min) (in combination with matrx)                 -9
# 5366  dry weight percent                                       -9
# 5367  length (max) (in combination with matrx)                 -9
# 5368  length (mean or individual) (in combination with matrx)  -9
# 5369  length (min) (in combination with matrx)                 -9
# 5370  dry weight percent                                       -9
# 5371  dry weight percent                                       -9
# 5372  extractable lipid percent                                -9
# 5373  extractable lipid percent                                -9
# 5374  fat weight percent                                       -9
# 5375  fat weight percent                                       -9
# 5376  length (max) (in combination with matrx)                 -9
# 5377  length (max) (in combination with matrx)                 -9
# 5378  length (mean or individual) (in combination with matrx)  -9
# 5379  length (mean or individual) (in combination with matrx)  -9
# 5380  length (min) (in combination with matrx)                 -9
# 5381  length (min) (in combination with matrx)                 -9
# 5382  weight (mean or individual) (in combination with matrx)  -9
# 5383  weight (mean or individual) (in combination with matrx)  -9
# 5384  dry weight percent                                       -9
# 5385  dry weight percent                                       -9
# 5386  dry weight percent                                       -9
# 5387  fat weight percent                                       -9
# 5388  length (max) (in combination with matrx)                 -9
# 5389  length (mean or individual) (in combination with matrx)  -9
# 5390  length (min) (in combination with matrx)                 -9
# 5391  % female population                                      -9
# 5392  % male population                                        -9
# 5393  % sterile females (IMPS 5-6, INTS 2 or above)            -9
# 5394  perfluorooctylsulfonate acid amide                       NV
#
#      DTYPE       PARAM  MUNIT    MATRX BASIS METPT METOA              Species  \
# 0     CS    ANT         ug/kg  SED1000  D     -9    -9    -9
# 1     CS    BAP         ug/kg  SED1000  D     -9    -9    -9
# 2     CS    CB101       ug/kg  SED1000  D     -9    -9    -9
# 3     CS    CB105       ug/kg  SED1000  D     -9    -9    -9
# 4     CS    CB118       ug/kg  SED1000  D     -9    -9    -9
# 5     CS    CB138       ug/kg  SED1000  D     -9    -9    -9
# 6     CS    CB153       ug/kg  SED1000  D     -9    -9    -9
# 7     CS    CB180       ug/kg  SED1000  D     -9    -9    -9
# 8     CS    CB28        ug/kg  SED1000  D     -9    -9    -9
# 9     CS    CB52        ug/kg  SED1000  D     -9    -9    -9
# 10    CS    CD          ug/kg  SED1000  D     -9    -9    -9
# 11    CS    CU          ug/kg  SED1000  D     -9    -9    -9
# 12    CS    DDEPP       ug/kg  SED1000  D     -9    -9    -9
# 13    CS    DDTOP       ug/kg  SED1000  D     -9    -9    -9
# 14    CS    DDTPP       ug/kg  SED1000  D     -9    -9    -9
# 15    CS    FLU         ug/kg  SED1000  D     -9    -9    -9
# 16    CS    HCB         ug/kg  SED1000  D     -9    -9    -9
# 17    CS    HG          ug/kg  SED1000  D     -9    -9    -9
# 18    CS    NAP         ug/kg  SED1000  D     -9    -9    -9
# 19    CS    PA          ug/kg  SED1000  D     -9    -9    -9
# 20    CS    PB          ug/kg  SED1000  D     -9    -9    -9
# 21    CS    TDEPP       ug/kg  SED1000  D     -9    -9    -9
# 22    CS    ZN          ug/kg  SED1000  D     -9    -9    -9
# 23    CS    AL          %      SED20    D     -9    -9    -9
# 24    CS    AL          g/kg   SED20    D     -9    -9    -9
# 25    CS    AL          mg/kg  SED20    D     -9    -9    -9
# 26    CS    AL          ug/kg  SED20    D     -9    -9    -9
# 27    CS    ANT         ug/kg  SED20    D     -9    -9    -9
# 28    CS    BAP         ug/kg  SED20    D     -9    -9    -9
# 29    CS    CB101       ug/kg  SED20    D     -9    -9    -9
# ...   ..      ...         ...    ...   ..     ..    ..    ..
# 5365  CF    LNMIN       -9     WO       -9    -9    -9    Mullus barbatus
# 5366  CF    DRYWT%      -9     SB       W     -9    -9    Mya truncata
# 5367  CF    LNMAX       -9     SH       -9    -9    -9    Mya truncata
# 5368  CF    LNMEA       -9     SH       -9    -9    -9    Mya truncata
# 5369  CF    LNMIN       -9     SH       -9    -9    -9    Mya truncata
# 5370  CF    DRYWT%      -9     SB       -9    -9    -9    Mytilus edulis
# 5371  CF    DRYWT%      -9     SB       W     -9    -9    Mytilus edulis
# 5372  CF    EXLIP%      -9     SB       -9    -9    -9    Mytilus edulis
# 5373  CF    EXLIP%      -9     SB       W     -9    -9    Mytilus edulis
# 5374  CF    FATWT%      -9     SB       -9    -9    -9    Mytilus edulis
# 5375  CF    FATWT%      -9     SB       W     -9    -9    Mytilus edulis
# 5376  CF    LNMAX       -9     SH       -9    -9    -9    Mytilus edulis
# 5377  CF    LNMAX       -9     WO       -9    -9    -9    Mytilus edulis
# 5378  CF    LNMEA       -9     SH       -9    -9    -9    Mytilus edulis
# 5379  CF    LNMEA       -9     WO       -9    -9    -9    Mytilus edulis
# 5380  CF    LNMIN       -9     SH       -9    -9    -9    Mytilus edulis
# 5381  CF    LNMIN       -9     WO       -9    -9    -9    Mytilus edulis
# 5382  CF    WTMEA       -9     EX       -9    -9    -9    Mytilus edulis
# 5383  CF    WTMEA       -9     SB       -9    -9    -9    Mytilus edulis
# 5384  CF    DRYWT%      -9     MU       -9    -9    -9    Nephrops norvegicus
# 5385  CF    DRYWT%      -9     MU       W     -9    -9    Nephrops norvegicus
# 5386  CF    DRYWT%      -9     TM       W     -9    -9    Nephrops norvegicus
# 5387  CF    FATWT%      -9     TM       W     -9    -9    Nephrops norvegicus
# 5388  CF    LNMAX       -9     WO       -9    -9    -9    Nephrops norvegicus
# 5389  CF    LNMEA       -9     WO       -9    -9    -9    Nephrops norvegicus
# 5390  CF    LNMIN       -9     WO       -9    -9    -9    Nephrops norvegicus
# 5391  CF    %FEMALEPOP  -9     SB       W     -9    -9    Nucella lapillus
# 5392  CF    %MALEPOP    -9     SB       W     -9    -9    Nucella lapillus
# 5393  CF    %STERF      -9     SB       W     -9    -9    Nucella lapillus
# 5394  CF    PFOSA       -9     SB       W     -9    -9    Mytilus edulis
#
#       AphiaID        Note S06_label      S07_label  \
# 0    -9        -9                    not specified
# 1    -9        -9                    not specified
# 2    -9        -9                    not specified
# 3    -9        -9                    not specified
# 4    -9        -9                    not specified
# 5    -9        -9                    not specified
# 6    -9        -9                    not specified
# 7    -9        -9                    not specified
# 8    -9        -9                    not specified
# 9    -9        -9                    not specified
# 10   -9        -9                    not specified
# 11   -9        -9                    not specified
# 12   -9        -9                    not specified
# 13   -9        -9                    not specified
# 14   -9        -9                    not specified
# 15   -9        -9                    not specified
# 16   -9        -9                    not specified
# 17   -9        -9                    not specified
# 18   -9        -9                    not specified
# 19   -9        -9                    not specified
# 20   -9        -9                    not specified
# 21   -9        -9                    not specified
# 22   -9        -9                    not specified
# 23   -9        -9                    not specified
# 24   -9        -9                    not specified
# 25   -9        -9                    not specified
# 26   -9        -9                    not specified
# 27   -9        -9                    not specified
# 28   -9        -9                    not specified
# 29   -9        -9                    not specified
# ...  ..        ..         ..                   ...
# 5365  126985   Fish                  not specified
# 5366  140431   Mollusca              not specified
# 5367  140431   Mollusca              not specified
# 5368  140431   Mollusca              not specified
# 5369  140431   Mollusca              not specified
# 5370  140480   Mollusca              not specified
# 5371  140480   Mollusca              not specified
# 5372  140480   Mollusca              not specified
# 5373  140480   Mollusca              not specified
# 5374  140480   Mollusca              not specified
# 5375  140480   Mollusca              not specified
# 5376  140480   Mollusca              not specified
# 5377  140480   Mollusca              not specified
# 5378  140480   Mollusca              not specified
# 5379  140480   Mollusca              not specified
# 5380  140480   Mollusca              not specified
# 5381  140480   Mollusca              not specified
# 5382  140480   Mollusca              not specified
# 5383  140480   Mollusca              not specified
# 5384  107254   Crustacean            not specified
# 5385  107254   Crustacean            not specified
# 5386  107254   Crustacean            not specified
# 5387  107254   Crustacean            not specified
# 5388  107254   Crustacean            not specified
# 5389  107254   Crustacean            not specified
# 5390  107254   Crustacean            not specified
# 5391  140403   Mollusca              not specified
# 5392  140403   Mollusca              not specified
# 5393  140403   Mollusca              not specified
# 5394  140480   Mollusca              not specified
#
#                                   S27_label
# 0     anthracene
# 1     benzo(a)pyrene
# 2     2,2',4,5,5'-pentachlorobiphenyl
# 3     2,3,3',4,4'-pentachlorobiphenyl
# 4     2,3',4,4',5-pentachlorobiphenyl
# 5     2,2',3,4,4',5'-hexachlorobiphenyl
# 6     2,2',4,4',5,5'-hexachlorobiphenyl
# 7     2,2',3,4,4',5,5'-heptachlorobiphenyl
# 8     2,4,4'-trichlorobiphenyl
# 9     2,2',5,5'-tetrachlorobiphenyl
# 10    NaN
# 11    NaN
# 12    4,4'-dichlorodiphenyldichloroethylene
# 13    2,4'-dichlorodiphenyltrichloroethane
# 14    4,4'-dichlorodiphenyltrichloroethane
# 15    fluoranthene
# 16    hexachlorobenzene
# 17    NaN
# 18    naphthalene
# 19    phenanthrene
# 20    NaN
# 21    4,4'-dichlorodiphenyldichloroethane
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    anthracene
# 28    benzo(a)pyrene
# 29    2,2',4,5,5'-pentachlorobiphenyl
# ...                               ...
# 5365  NaN
# 5366  NaN
# 5367  NaN
# 5368  NaN
# 5369  NaN
# 5370  NaN
# 5371  NaN
# 5372  NaN
# 5373  NaN
# 5374  NaN
# 5375  NaN
# 5376  NaN
# 5377  NaN
# 5378  NaN
# 5379  NaN
# 5380  NaN
# 5381  NaN
# 5382  NaN
# 5383  NaN
# 5384  NaN
# 5385  NaN
# 5386  NaN
# 5387  NaN
# 5388  NaN
# 5389  NaN
# 5390  NaN
# 5391  NaN
# 5392  NaN
# 5393  NaN
# 5394  NaN
#
# [5395 rows x 15 columns]

# %% [markdown]
# ### For the contents of the input file determine if any new local PARAM to S27 mappings are required for chemical PARAMs

# %%
display(param_combo[(param_combo['S27'].isnull()) & (param_combo['CAS']!='-9')][['PRNAM','CAS','PARAM','S27','S27_label','SOURCE']].drop_duplicates().sort_values('CAS'))
# Out:
#                                                                     PRNAM  \
# 336   cis-heptachlorepoxide "(alpha)"
# 245   2,3',4,4'-tetrabromodiphenyl ether (BDE66)
# 357   oxychlordane
# 23    aluminium
# 20    lead
# 47    lithium
# 17    mercury
# 355   nickel
# 502   arsenic
# 10    cadmium
# 121   chromium
# 11    copper
# 22    zinc
# 228   benzo[b+j,k]fluoranthene
# 5041  tetra-bromodiphenyl ether (sum of congeners)
# 5037  octa-bromodiphenyl ether (sum of congeners)
# 5036  nonabromodiphenyl ether (sum of congeners)
# 5035  hexa-bromodiphenyl ether (sum of congeners)
# 5034  hepta-bromodiphenyl ether (sum of congeners)
# 5033  DDT (p,p') + DDE (p,p')
# 4988  sum of CBs.- Sum of (CB28, CB52, CB101, CB118, CB138, CB153, CB180)
# 4987  penta-bromodiphenyl ether (sum of congeners)
# 4985  1,2,3,4,7,8/1,2,3,4,7,9-hexachloro-dibenzofuran
# 182   triphenyltin - expressed as Sn-atom
# 4984  CB56 + CB60
# 4983  CB138 + CB163
# 511   benzo[b+k]fluoranthene
# 5042  tri-bromodiphenyl ether (sum of congeners)
# 303   chrysene + triphenylene
# 170   tributyltin (TBT) - expressed as Sn-atom
# 4986  octachloro-dibenzofuran (group)
# 5394  perfluorooctylsulfonate acid amide
#
#               CAS      PARAM  S27 S27_label SOURCE
# 336   1024-57-3    HCEPC      NaN  NaN       NaN
# 245   189084-61-5  BDE66      NaN  NaN       NaN
# 357   26880-48-8   OCDAN      NaN  NaN       NaN
# 23    7429-90-5    AL         NaN  NaN       NaN
# 20    7439-92-1    PB         NaN  NaN       NaN
# 47    7439-93-2    LI         NaN  NaN       NaN
# 17    7439-97-6    HG         NaN  NaN       NaN
# 355   7440-02-0    NI         NaN  NaN       NaN
# 502   7440-38-2    AS         NaN  NaN       NaN
# 10    7440-43-9    CD         NaN  NaN       NaN
# 121   7440-47-3    CR         NaN  NaN       NaN
# 11    7440-50-8    CU         NaN  NaN       NaN
# 22    7440-66-6    ZN         NaN  NaN       NaN
# 228   GM           BBJKF      NaN  NaN       NaN
# 5041  GM           TEBDE      NaN  NaN       NaN
# 5037  GM           OBDE       NaN  NaN       NaN
# 5036  GM           NBDE       NaN  NaN       NaN
# 5035  GM           HXBDE      NaN  NaN       NaN
# 5034  GM           HPBDE      NaN  NaN       NaN
# 5033  GM           DDTEP      NaN  NaN       NaN
# 4988  GM           SCB7       NaN  NaN       NaN
# 4987  GM           PEBDE      NaN  NaN       NaN
# 4985  GM           CDFDX      NaN  NaN       NaN
# 182   GM           TPTIN      NaN  NaN       NaN
# 4984  GM           CB56+60    NaN  NaN       NaN
# 4983  GM           CB138+163  NaN  NaN       NaN
# 511   GM           BBKF       NaN  NaN       NaN
# 5042  GM           TRBDE      NaN  NaN       NaN
# 303   GM           CHRTR      NaN  NaN       NaN
# 170   GM           TBTIN      NaN  NaN       NaN
# 4986  GM           CDFO       NaN  NaN       NaN
# 5394  NV           PFOSA      NaN  NaN       NaN

# %% [markdown]
# ### Check no chemical codes present among those rows without a CAS entry

# %%
display(param_combo[(param_combo['S27'].isnull()) & (param_combo['CAS']=='-9')][['PRNAM','CAS','PARAM','S27','S27_label','SOURCE']].drop_duplicates().sort_values('CAS'))
# Out:
#                                                                                               PRNAM  \
# 140   Grain Size Mass Fraction <1000 micron
# 5391  % female population
# 5091  weight (minimum) (in combination with matrx)
# 5089  weight (mean or individual) (in combination with matrx)
# 5088  weight (maximum) (in combination with matrx)
# 5074  age (min)
# 5073  age (mean)
# 5072  age (max)
# 5056  length (min) (in combination with matrx)
# 5054  length (max) (in combination with matrx)
# 5052  fat weight percent
# 5051  extractable lipid percent
# 5049  dry weight percent
# 5048  Vas Deferens Sequence Index (mean of VDS stages scored) (imposex)
# 5047  Vas Deferens Sequence (stages 0-6) (imposex)
# 5046  Relative Penis Size Index (%) ((mean female penis length)^3/(mean male penis length)^3) x 100
# 5045  length of male penis (mm) (imposex)
# 5044  length (mean or individual) (in combination with matrx)
# 5043  length of female penis (mm) (imposex)
# 721   turbidity
# 704   suspended solids
# 157   moisture content percent
# 156   loss on ignition
# 143   Grain Size Mass Fraction <63 micron (silt/clay)
# 142   Grain Size Mass Fraction <2000 micron
# 141   Grain Size Mass Fraction <125 micron
# 5392  % male population
# 5393  % sterile females (IMPS 5-6, INTS 2 or above)
#
#      CAS       PARAM  S27 S27_label SOURCE
# 140   -9  GSMF1000    NaN  NaN       NaN
# 5391  -9  %FEMALEPOP  NaN  NaN       NaN
# 5091  -9  WTMIN       NaN  NaN       NaN
# 5089  -9  WTMEA       NaN  NaN       NaN
# 5088  -9  WTMAX       NaN  NaN       NaN
# 5074  -9  AGMIN       NaN  NaN       NaN
# 5073  -9  AGMEA       NaN  NaN       NaN
# 5072  -9  AGMAX       NaN  NaN       NaN
# 5056  -9  LNMIN       NaN  NaN       NaN
# 5054  -9  LNMAX       NaN  NaN       NaN
# 5052  -9  FATWT%      NaN  NaN       NaN
# 5051  -9  EXLIP%      NaN  NaN       NaN
# 5049  -9  DRYWT%      NaN  NaN       NaN
# 5048  -9  VDSI        NaN  NaN       NaN
# 5047  -9  VDS         NaN  NaN       NaN
# 5046  -9  RPSI        NaN  NaN       NaN
# 5045  -9  LNMPE       NaN  NaN       NaN
# 5044  -9  LNMEA       NaN  NaN       NaN
# 5043  -9  LNFPE       NaN  NaN       NaN
# 721   -9  TURB        NaN  NaN       NaN
# 704   -9  SUSP        NaN  NaN       NaN
# 157   -9  MOCON%      NaN  NaN       NaN
# 156   -9  LOIGN       NaN  NaN       NaN
# 143   -9  GSMF63      NaN  NaN       NaN
# 142   -9  GSMF2000    NaN  NaN       NaN
# 141   -9  GSMF125     NaN  NaN       NaN
# 5392  -9  %MALEPOP    NaN  NaN       NaN
# 5393  -9  %STERF      NaN  NaN       NaN

# %% [markdown]
# #### Where mappings don't exist for chemical PARAMs or can't be made via CAS number as listed above:
# #### Either:
# #### - Add mapping to local file and re-run previous steps
# #### - Continue process and these rows will not be able to be mapped to a P01 term

# %%
# Mark rows that require chemical substance mapping with S27 as "manual mapping required"
param_combo.loc[(param_combo['S27'].isnull()) & (param_combo['CAS']!='-9'),'S27_label'] = 'manual mapping required'
# Mark rows that do not require chemical substance mapping with S27 as "not applicable"    
param_combo.loc[(param_combo['S27'].isnull()) & (param_combo['CAS']=='-9'),'S27_label'] = 'not applicable'

# Generate list of new substances to be added to S27
S27_cols = ['PARGROUP','PARAM','PRNAM','CAS','S27_label','S27']
S27new = param_combo[param_combo['S27_label']=='manual mapping required'][S27_cols].drop_duplicates().reset_index(drop=True)

S27new_file = os.path.join(results,'new_S27.csv')
S27new.to_csv(S27new_file, index=False)
print("Subset of new S27 terms for creation or manual mapping saved to: %s" % S27new_file)

# Generate list of PARAMs to be mapped to another element of the semantic model
altmap_cols = ['PARGROUP','PARAM','PRNAM','CAS']
alt_mapping = param_combo[param_combo['S27_label']=='not applicable'][altmap_cols].drop_duplicates().reset_index(drop=True)

altmap_file = os.path.join(results,'alt_mappings.csv')
alt_mapping.to_csv(altmap_file, index=False)
print("Subset of PARAMs for creation or manual mapping to another part of the semantic model saved to: %s" % altmap_file)

print("Total combinations = %s" % (len(param_combo)))

PARAMs2map = pd.DataFrame()
PARAMs2map = param_combo[['PARAM','PRNAM']][param_combo['S27_label']=='not applicable'].drop_duplicates()
# Out:
# Subset of new S27 terms for creation or manual mapping saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\new_S27.csv
# Subset of PARAMs for creation or manual mapping to another part of the semantic model saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\alt_mappings.csv
# Total combinations = 5395

# %% [markdown]
# ## Mapping of ICS DTYPE, MATRX and METPT combinations to P01 semantic component S26
#
# <img align="left" style="padding-right:10px;" src="img/matrix_mapping.png"></br>

# %%
matrix_check = param_combo[['DTYPE','MATRX','METPT']].drop_duplicates().copy(deep=True).reset_index(drop=True)

# Set to default of 'Check MATRX. Not mapped.'
matrix_check = matrix_check.assign(S26_label = 'Check DTYPE/MATRX/METPT combination. Not mapped.')

print("Number of MATRX for P01 mapping: %s" % len(matrix_check))
summary.append(["Number of MATRX for P01 mapping:" , len(matrix_check)])

for index, row in matrix_check.iterrows():
    if row['DTYPE'] == 'CF':
        # Set S26 label to 'biota'
        row['S26_label'] = 'biota'

    elif row['DTYPE'] == 'CS':
        if row['MATRX'] == 'SEDTOT':
            row['S26_label'] = 'sediment'
        elif row['MATRX'][3:len(row['MATRX'])] != 'TOT':
            row['S26_label'] = 'sediment <'+row['MATRX'][3:len(row['MATRX'])] +'um'
            
    elif row['DTYPE'] == 'CW':
        if row['MATRX'] == 'WT':
            if row['METPT'] == '-9':
                row['S26_label'] = 'water body [dissolved plus reactive particulate <unknown phase]'
            else:
                metpt_list = row['METPT'].split('~')               
                for metpt in metpt_list:
                    if metpt in ('NF','NONE','NA','CP'):
                        row['S26_label'] = 'water body [dissolved plus reactive particulate phase]'
                        continue
                    elif metpt in('GFF','GF/F','FF-GF-0.7'):
                        row['S26_label'] = 'water body [dissolved plus reactive particulate <GF/F phase]'
                        continue
                    elif metpt in('GFC','GF/C','FF-GF-1.2','FF-PP-1.2'):
                        row['S26_label'] = 'water body [dissolved plus reactive particulate <GF/C phase]'
                        continue
                    elif metpt in('FM-PC-0.4','FM-PC-0.45','FM-PES-0.45','FM-CN-0.45','FM-CA-0.45','PCF40','PCF45','PCF'):
                        row['S26_label'] = 'water body [dissolved plus reactive particulate <0.4/0.45um phase]'
                        continue
                    elif metpt in('F'):
                        row['S26_label'] = 'water body [dissolved plus reactive particulate <unknown phase]'
                        continue
                    elif metpt in('FM-CA-0.2'):
                        row['S26_label'] = 'water body [dissolved plus reactive particulate <0.2um phase]'
                        continue

    #print("Row %s of %s matrix combinations mapped." % (index+1,len(matrix_check))) # Commented out used in debugging
#display(matrix_check)    

# Subset potential S26 new entries
S26new = matrix_check[matrix_check['S26_label']=='Check DTYPE/MATRX/METPT combination. Not mapped.']

print("Number of potential new S26 terms: %s" % len(S26new))
summary.append(["Number of potential new S26 terms:" , len(S26new)])
display(S26new)

# Retain those combinations that have not yet been mapped to P01
S26new_file = os.path.join(results,'new_S26.csv')
S26new.to_csv(S26new_file, index=False)
print("Subset of new S26 terms for creation saved to: %s" % S26new_file)

# Add S26 semantic model mapping to the main table based on the combinations provided   
param_combo = pd.merge(param_combo, matrix_check, how='left', on=['DTYPE','MATRX','METPT'])

print("Total combinations = %s" % (len(param_combo)))
# Out:
# Number of MATRX for P01 mapping: 64
# Number of potential new S26 terms: 5
#    DTYPE MATRX      METPT                                         S26_label
# 8   CW    SPM   NONE       Check DTYPE/MATRX/METPT combination. Not mapped.
# 9   CW    SPM   FM-PC-0.4  Check DTYPE/MATRX/METPT combination. Not mapped.
# 10  CW    SPM   NF         Check DTYPE/MATRX/METPT combination. Not mapped.
# 11  CW    SPM   FF-GF-1.2  Check DTYPE/MATRX/METPT combination. Not mapped.
# 12  CW    SPM   GFC1.2     Check DTYPE/MATRX/METPT combination. Not mapped.
# Subset of new S26 terms for creation saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\new_S26.csv
# Total combinations = 5395

# %% [markdown]
# ### Display mapping progress

# %%
display(param_combo[['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note','S06_label','S07_label','S27_label','S26_label']])
# Out:
#                                                         PRNAM         CAS  \
# 0     anthracene                                               120-12-7
# 1     benzo[a]pyrene                                           50-32-8
# 2     2,2',4,5,5'-pentachlorobiphenyl (CB101)                  37680-73-2
# 3     2,3,3',4,4'-pentachlorobiphenyl (CB105)                  32598-14-4
# 4     2,3',4,4',5-pentachlorobiphenyl (CB118)                  31508-00-6
# 5     2,2',3,4,4',5'-hexachlorobiphenyl (CB138)                35065-28-2
# 6     2,2',4,4',5,5'-hexachlorobiphenyl (CB153)                35065-27-1
# 7     2,2',3,4,4',5,5'-heptachlorobiphenyl (CB180)             35065-29-3
# 8     2,4,4'-trichlorobiphenyl (CB28)                          7012-37-5
# 9     2,2',5,5'-tetrachlorobiphenyl (CB52)                     35693-99-3
# 10    cadmium                                                  7440-43-9
# 11    copper                                                   7440-50-8
# 12    DDE (p,p')                                               72-55-9
# 13    DDT (o,p')                                               789-02-6
# 14    DDT (p,p')                                               50-29-3
# 15    fluoranthene                                             206-44-0
# 16    hexachlorobenzene                                        118-74-1
# 17    mercury                                                  7439-97-6
# 18    naphthalene                                              91-20-3
# 19    phenanthrene                                             85-01-8
# 20    lead                                                     7439-92-1
# 21    TDE (p,p') = DDD (p,p')                                  72-54-8
# 22    zinc                                                     7440-66-6
# 23    aluminium                                                7429-90-5
# 24    aluminium                                                7429-90-5
# 25    aluminium                                                7429-90-5
# 26    aluminium                                                7429-90-5
# 27    anthracene                                               120-12-7
# 28    benzo[a]pyrene                                           50-32-8
# 29    2,2',4,5,5'-pentachlorobiphenyl (CB101)                  37680-73-2
# ...                                       ...                         ...
# 5365  length (min) (in combination with matrx)                 -9
# 5366  dry weight percent                                       -9
# 5367  length (max) (in combination with matrx)                 -9
# 5368  length (mean or individual) (in combination with matrx)  -9
# 5369  length (min) (in combination with matrx)                 -9
# 5370  dry weight percent                                       -9
# 5371  dry weight percent                                       -9
# 5372  extractable lipid percent                                -9
# 5373  extractable lipid percent                                -9
# 5374  fat weight percent                                       -9
# 5375  fat weight percent                                       -9
# 5376  length (max) (in combination with matrx)                 -9
# 5377  length (max) (in combination with matrx)                 -9
# 5378  length (mean or individual) (in combination with matrx)  -9
# 5379  length (mean or individual) (in combination with matrx)  -9
# 5380  length (min) (in combination with matrx)                 -9
# 5381  length (min) (in combination with matrx)                 -9
# 5382  weight (mean or individual) (in combination with matrx)  -9
# 5383  weight (mean or individual) (in combination with matrx)  -9
# 5384  dry weight percent                                       -9
# 5385  dry weight percent                                       -9
# 5386  dry weight percent                                       -9
# 5387  fat weight percent                                       -9
# 5388  length (max) (in combination with matrx)                 -9
# 5389  length (mean or individual) (in combination with matrx)  -9
# 5390  length (min) (in combination with matrx)                 -9
# 5391  % female population                                      -9
# 5392  % male population                                        -9
# 5393  % sterile females (IMPS 5-6, INTS 2 or above)            -9
# 5394  perfluorooctylsulfonate acid amide                       NV
#
#      DTYPE       PARAM  MUNIT    MATRX BASIS METPT METOA              Species  \
# 0     CS    ANT         ug/kg  SED1000  D     -9    -9    -9
# 1     CS    BAP         ug/kg  SED1000  D     -9    -9    -9
# 2     CS    CB101       ug/kg  SED1000  D     -9    -9    -9
# 3     CS    CB105       ug/kg  SED1000  D     -9    -9    -9
# 4     CS    CB118       ug/kg  SED1000  D     -9    -9    -9
# 5     CS    CB138       ug/kg  SED1000  D     -9    -9    -9
# 6     CS    CB153       ug/kg  SED1000  D     -9    -9    -9
# 7     CS    CB180       ug/kg  SED1000  D     -9    -9    -9
# 8     CS    CB28        ug/kg  SED1000  D     -9    -9    -9
# 9     CS    CB52        ug/kg  SED1000  D     -9    -9    -9
# 10    CS    CD          ug/kg  SED1000  D     -9    -9    -9
# 11    CS    CU          ug/kg  SED1000  D     -9    -9    -9
# 12    CS    DDEPP       ug/kg  SED1000  D     -9    -9    -9
# 13    CS    DDTOP       ug/kg  SED1000  D     -9    -9    -9
# 14    CS    DDTPP       ug/kg  SED1000  D     -9    -9    -9
# 15    CS    FLU         ug/kg  SED1000  D     -9    -9    -9
# 16    CS    HCB         ug/kg  SED1000  D     -9    -9    -9
# 17    CS    HG          ug/kg  SED1000  D     -9    -9    -9
# 18    CS    NAP         ug/kg  SED1000  D     -9    -9    -9
# 19    CS    PA          ug/kg  SED1000  D     -9    -9    -9
# 20    CS    PB          ug/kg  SED1000  D     -9    -9    -9
# 21    CS    TDEPP       ug/kg  SED1000  D     -9    -9    -9
# 22    CS    ZN          ug/kg  SED1000  D     -9    -9    -9
# 23    CS    AL          %      SED20    D     -9    -9    -9
# 24    CS    AL          g/kg   SED20    D     -9    -9    -9
# 25    CS    AL          mg/kg  SED20    D     -9    -9    -9
# 26    CS    AL          ug/kg  SED20    D     -9    -9    -9
# 27    CS    ANT         ug/kg  SED20    D     -9    -9    -9
# 28    CS    BAP         ug/kg  SED20    D     -9    -9    -9
# 29    CS    CB101       ug/kg  SED20    D     -9    -9    -9
# ...   ..      ...         ...    ...   ..     ..    ..    ..
# 5365  CF    LNMIN       -9     WO       -9    -9    -9    Mullus barbatus
# 5366  CF    DRYWT%      -9     SB       W     -9    -9    Mya truncata
# 5367  CF    LNMAX       -9     SH       -9    -9    -9    Mya truncata
# 5368  CF    LNMEA       -9     SH       -9    -9    -9    Mya truncata
# 5369  CF    LNMIN       -9     SH       -9    -9    -9    Mya truncata
# 5370  CF    DRYWT%      -9     SB       -9    -9    -9    Mytilus edulis
# 5371  CF    DRYWT%      -9     SB       W     -9    -9    Mytilus edulis
# 5372  CF    EXLIP%      -9     SB       -9    -9    -9    Mytilus edulis
# 5373  CF    EXLIP%      -9     SB       W     -9    -9    Mytilus edulis
# 5374  CF    FATWT%      -9     SB       -9    -9    -9    Mytilus edulis
# 5375  CF    FATWT%      -9     SB       W     -9    -9    Mytilus edulis
# 5376  CF    LNMAX       -9     SH       -9    -9    -9    Mytilus edulis
# 5377  CF    LNMAX       -9     WO       -9    -9    -9    Mytilus edulis
# 5378  CF    LNMEA       -9     SH       -9    -9    -9    Mytilus edulis
# 5379  CF    LNMEA       -9     WO       -9    -9    -9    Mytilus edulis
# 5380  CF    LNMIN       -9     SH       -9    -9    -9    Mytilus edulis
# 5381  CF    LNMIN       -9     WO       -9    -9    -9    Mytilus edulis
# 5382  CF    WTMEA       -9     EX       -9    -9    -9    Mytilus edulis
# 5383  CF    WTMEA       -9     SB       -9    -9    -9    Mytilus edulis
# 5384  CF    DRYWT%      -9     MU       -9    -9    -9    Nephrops norvegicus
# 5385  CF    DRYWT%      -9     MU       W     -9    -9    Nephrops norvegicus
# 5386  CF    DRYWT%      -9     TM       W     -9    -9    Nephrops norvegicus
# 5387  CF    FATWT%      -9     TM       W     -9    -9    Nephrops norvegicus
# 5388  CF    LNMAX       -9     WO       -9    -9    -9    Nephrops norvegicus
# 5389  CF    LNMEA       -9     WO       -9    -9    -9    Nephrops norvegicus
# 5390  CF    LNMIN       -9     WO       -9    -9    -9    Nephrops norvegicus
# 5391  CF    %FEMALEPOP  -9     SB       W     -9    -9    Nucella lapillus
# 5392  CF    %MALEPOP    -9     SB       W     -9    -9    Nucella lapillus
# 5393  CF    %STERF      -9     SB       W     -9    -9    Nucella lapillus
# 5394  CF    PFOSA       -9     SB       W     -9    -9    Mytilus edulis
#
#       AphiaID        Note S06_label      S07_label  \
# 0    -9        -9                    not specified
# 1    -9        -9                    not specified
# 2    -9        -9                    not specified
# 3    -9        -9                    not specified
# 4    -9        -9                    not specified
# 5    -9        -9                    not specified
# 6    -9        -9                    not specified
# 7    -9        -9                    not specified
# 8    -9        -9                    not specified
# 9    -9        -9                    not specified
# 10   -9        -9                    not specified
# 11   -9        -9                    not specified
# 12   -9        -9                    not specified
# 13   -9        -9                    not specified
# 14   -9        -9                    not specified
# 15   -9        -9                    not specified
# 16   -9        -9                    not specified
# 17   -9        -9                    not specified
# 18   -9        -9                    not specified
# 19   -9        -9                    not specified
# 20   -9        -9                    not specified
# 21   -9        -9                    not specified
# 22   -9        -9                    not specified
# 23   -9        -9                    not specified
# 24   -9        -9                    not specified
# 25   -9        -9                    not specified
# 26   -9        -9                    not specified
# 27   -9        -9                    not specified
# 28   -9        -9                    not specified
# 29   -9        -9                    not specified
# ...  ..        ..         ..                   ...
# 5365  126985   Fish                  not specified
# 5366  140431   Mollusca              not specified
# 5367  140431   Mollusca              not specified
# 5368  140431   Mollusca              not specified
# 5369  140431   Mollusca              not specified
# 5370  140480   Mollusca              not specified
# 5371  140480   Mollusca              not specified
# 5372  140480   Mollusca              not specified
# 5373  140480   Mollusca              not specified
# 5374  140480   Mollusca              not specified
# 5375  140480   Mollusca              not specified
# 5376  140480   Mollusca              not specified
# 5377  140480   Mollusca              not specified
# 5378  140480   Mollusca              not specified
# 5379  140480   Mollusca              not specified
# 5380  140480   Mollusca              not specified
# 5381  140480   Mollusca              not specified
# 5382  140480   Mollusca              not specified
# 5383  140480   Mollusca              not specified
# 5384  107254   Crustacean            not specified
# 5385  107254   Crustacean            not specified
# 5386  107254   Crustacean            not specified
# 5387  107254   Crustacean            not specified
# 5388  107254   Crustacean            not specified
# 5389  107254   Crustacean            not specified
# 5390  107254   Crustacean            not specified
# 5391  140403   Mollusca              not specified
# 5392  140403   Mollusca              not specified
# 5393  140403   Mollusca              not specified
# 5394  140480   Mollusca              not specified
#
#                                   S27_label         S26_label
# 0     anthracene                             sediment <1000um
# 1     benzo(a)pyrene                         sediment <1000um
# 2     2,2',4,5,5'-pentachlorobiphenyl        sediment <1000um
# 3     2,3,3',4,4'-pentachlorobiphenyl        sediment <1000um
# 4     2,3',4,4',5-pentachlorobiphenyl        sediment <1000um
# 5     2,2',3,4,4',5'-hexachlorobiphenyl      sediment <1000um
# 6     2,2',4,4',5,5'-hexachlorobiphenyl      sediment <1000um
# 7     2,2',3,4,4',5,5'-heptachlorobiphenyl   sediment <1000um
# 8     2,4,4'-trichlorobiphenyl               sediment <1000um
# 9     2,2',5,5'-tetrachlorobiphenyl          sediment <1000um
# 10    manual mapping required                sediment <1000um
# 11    manual mapping required                sediment <1000um
# 12    4,4'-dichlorodiphenyldichloroethylene  sediment <1000um
# 13    2,4'-dichlorodiphenyltrichloroethane   sediment <1000um
# 14    4,4'-dichlorodiphenyltrichloroethane   sediment <1000um
# 15    fluoranthene                           sediment <1000um
# 16    hexachlorobenzene                      sediment <1000um
# 17    manual mapping required                sediment <1000um
# 18    naphthalene                            sediment <1000um
# 19    phenanthrene                           sediment <1000um
# 20    manual mapping required                sediment <1000um
# 21    4,4'-dichlorodiphenyldichloroethane    sediment <1000um
# 22    manual mapping required                sediment <1000um
# 23    manual mapping required                sediment <20um
# 24    manual mapping required                sediment <20um
# 25    manual mapping required                sediment <20um
# 26    manual mapping required                sediment <20um
# 27    anthracene                             sediment <20um
# 28    benzo(a)pyrene                         sediment <20um
# 29    2,2',4,5,5'-pentachlorobiphenyl        sediment <20um
# ...                               ...                   ...
# 5365  not applicable                         biota
# 5366  not applicable                         biota
# 5367  not applicable                         biota
# 5368  not applicable                         biota
# 5369  not applicable                         biota
# 5370  not applicable                         biota
# 5371  not applicable                         biota
# 5372  not applicable                         biota
# 5373  not applicable                         biota
# 5374  not applicable                         biota
# 5375  not applicable                         biota
# 5376  not applicable                         biota
# 5377  not applicable                         biota
# 5378  not applicable                         biota
# 5379  not applicable                         biota
# 5380  not applicable                         biota
# 5381  not applicable                         biota
# 5382  not applicable                         biota
# 5383  not applicable                         biota
# 5384  not applicable                         biota
# 5385  not applicable                         biota
# 5386  not applicable                         biota
# 5387  not applicable                         biota
# 5388  not applicable                         biota
# 5389  not applicable                         biota
# 5390  not applicable                         biota
# 5391  not applicable                         biota
# 5392  not applicable                         biota
# 5393  not applicable                         biota
# 5394  manual mapping required                biota
#
# [5395 rows x 16 columns]

# %% [markdown]
# # Taxon, WoRMS AphiaID, ITIS TSN combination check

# %%
# Get all existing TAXONs from S25 and simplify text labels to show distinct TAXON values from the S25 semantic model
url = """http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0A++++PREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A++++++++++++++++++++%0D%0A++++select+distinct+%3FAphiaID+%3FTAXON%0D%0A++++where+%7B%0D%0A+++++++++++%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furl+.%0D%0A+++++++++++%3Furl+skos%3AprefLabel+%3FprefLabel+.%0D%0A+++++++++++%3Furl+owl%3Adeprecated+%27false%27+.%0D%0A+++++++++++FILTER%28regex%28str%28%3FprefLabel%29%2C+%22WoRMS%22%2C+%22i%22%29%29+.%0D%0A+++++++++++BIND%28replace%28str%28%3FprefLabel%29%2C+%22%5C%5C+%5C%5C%5B.*%3F%5C%5C%5D%22%2C%22%22%2C+%22i%22%29+AS+%3FTAXON%29+.%0D%0A+++++++++++BIND%28replace%28replace%28replace%28str%28%3FTAXON%29%2C+%22%5C%5C%29%22%2C%22%22%2C+%22i%22%29%2C+%22.*%28%3F%3DWoRMS+%29%22%2C+%22%22%2C+%22i%22%29%2C+%22WoRMS+%22%2C+%22%22%2C+%22i%22%29+AS+%3FAphiaID%29+.%0D%0A++++++++++%7D%0D%0A++++order+by+%3FAphiaID%0D%0A&output=CSV&stylesheet=CSV"""

S25taxon = pd.read_csv(url)

# Identify multiple TAXONs per AphiaID within S25
S25taxon_duplicates = S25taxon[S25taxon.duplicated(['AphiaID'], keep=False)].copy(deep=True)
S25taxon_duplicates.replace(u'\xc2\xa0',u' ', regex=True, inplace=True)
S25taxon_duplicates.replace(u'\u2019',u"'", regex=True, inplace=True)

# Remove duplicate TAXON records from S25taxon dataframe
S25taxon_clean = pd.concat([S25taxon, S25taxon_duplicates]).drop_duplicates(keep=False).copy(deep=True).reset_index(drop=True)

# Create a Pandas DataFrame and populate with unique combinations of Species and AphiaID from the input file
input_taxa_check = pd.DataFrame()
input_taxa_check = param_combo[['Species','AphiaID']][param_combo['Species']!='-9'].drop_duplicates().reset_index(drop=True)
input_taxa_check = input_taxa_check.astype({"AphiaID": int})

print("Number of Species for P01 mapping: %s" % len(input_taxa_check))
summary.append(["Number of Species for P01 mapping:" , len(input_taxa_check)])
#%%
# Function to call WoRMS web service
def worms_check(url):
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    if response.code==204:
        e = 'No AphiaID found.'
    elif response.code==206:
        e = 'Multiple AphiaID found.'
    elif response.code==200:
        e = response.read()
    return e

# If AphiaID is absent then lookup using the WoRMS web service
for index, row in input_taxa_check.iterrows():
    if row['AphiaID'] == -9:
        if '&' not in row['Species']:
            url = 'http://marinespecies.org/rest/AphiaIDByName/%s?marine_only=true' % row['Species'].replace(" ","%20")
            input_taxa_check.loc[index, 'AphiaID'] = worms_check(url)
        else:
            input_taxa_check.loc[index, 'AphiaID'] = 'Combination of taxa'

inputs_aphia = pd.merge(inputs, input_taxa_check, on='Species')


#%% 
# Get WoRMS scientific names from AphiaID provided using WoRMS web service
def worms_check(url):
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    if response.code==204:
        list.append('No response.')
    elif response.code==200:
        e = response.read()
    return json.loads(e)
       
worms = pd.DataFrame()        

aphia_list = input_taxa_check['AphiaID'].tolist()
y = len(aphia_list)
if y<50:
    ids = ''
    for i in range(0,50):
        ids = ids + 'aphiaids%5B%5D=' + str(aphia_list[i]) + '&'
    url = 'http://www.marinespecies.org/rest/AphiaRecordsByAphiaIDs?%s' % ids[0:-1]
    worms = pd.DataFrame(worms_check(url), ignore_index=True)
elif y>50:
    for j in range(0,int(y/50)):
        ids = ''
        for i in range(j*50,min((j+1)*50,y)):
            ids = ids + 'aphiaids%5B%5D=' + str(aphia_list[i]) + '&'
        url = 'http://www.marinespecies.org/rest/AphiaRecordsByAphiaIDs?%s' % ids[0:-1]
        worms = pd.concat([worms, pd.DataFrame(worms_check(url))], ignore_index=True)
    ids = ''
    for i in range((j+1)*50,min((j+2)*50,y)):
        ids = ids + 'aphiaids%5B%5D=' + str(aphia_list[i]) + '&'
    url = 'http://www.marinespecies.org/rest/AphiaRecordsByAphiaIDs?%s' % ids[0:-1]
    worms = pd.concat([worms, pd.DataFrame(worms_check(url))], ignore_index=True)

input_taxa_check = pd.merge(input_taxa_check, worms[['AphiaID','scientificname']], how='left', on='AphiaID')

input_taxa_check = input_taxa_check.rename(index=str, columns={'scientificname': 'name_from_AphiaID'})

# Set column to indicate if a discrepancy to be resolved exists based on Scientific names not matching
a = input_taxa_check.Species == input_taxa_check.name_from_AphiaID
input_taxa_check['proceed'] = np.where(a, 'Yes', 'No')

# Subset those taxa where naming discrepancy exists
taxa_discrepancy = input_taxa_check[input_taxa_check['proceed']=='No'].reset_index(drop=True)

print("Number of Species with name discrepancy between taxon-AphiaID combination in file and WoRMS: %s" % len(taxa_discrepancy))
summary.append(["Number of Species with name discrepancy between taxon-AphiaID combination in file and WoRMS:" , len(taxa_discrepancy)])
display(taxa_discrepancy)

# Save taxa discrepancies
taxadis_file = os.path.join(results,'taxa_discrepancy.csv')
taxa_discrepancy.to_csv(taxadis_file, index=False)
print("Taxa discrepancies saved to: %s" % taxadis_file)

# Map AphiaID to S25 component TAXON for the non-duplicate AphiaID results in S25
taxa_map = pd.merge(input_taxa_check[['AphiaID','name_from_AphiaID']],
                    S25taxon_clean, 
                    how='left', 
                    on='AphiaID')
taxa_map = taxa_map.fillna(value={'TAXON': 'New TAXON required.'}).drop_duplicates()


# Add TAXON mapping to the main table based on the AphiaID provided    
param_combo = pd.merge(param_combo, taxa_map, how='left', on='AphiaID')

# Mark rows that do not require mapping as "Not applicable."    
param_combo = param_combo.fillna(value={'TAXON': 'not specified', 'name_from_AphiaID': '-9'})

print("Total combinations = %s" % (len(param_combo)))
# Out:
# Number of Species for P01 mapping: 116
# Number of Species with name discrepancy between taxon-AphiaID combination in file and WoRMS: 9
#                    Species  AphiaID        name_from_AphiaID proceed
# 0  Venerupis philippinarum  231750   Ruditapes philippinarum  No
# 1  Psetta maxima            127149   Scophthalmus maximus     No
# 2  Phoca hispida            159021   Pusa hispida             No
# 3  Mysidacea                149668   Mysida                   No
# 4  Raja radiata             105865   Amblyraja radiata        No
# 5  Clupea harengus membras  126417   Clupea harengus          No
# 6  Clupea harengus membras  126417   Clupea harengus          No
# 7  Sebastes marinus         151324   Sebastes norvegicus      No
# 8  Macoma baltica           880017   Limecola balthica        No
# Taxa discrepancies saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\taxa_discrepancy.csv
# Total combinations = 5395

# %% [markdown]
# ### Display mapping progress

# %%
display(param_combo[(param_combo['DTYPE']=='CF')][['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note','S06_label','S07_label','S27_label','S26_label','TAXON']])
# Out:
#                                                         PRNAM         CAS  \
# 748   Benzene, 1-bromo-2-phenoxy- (PBDE1)                      7025-06-01
# 749   Benzene, 1-bromo-4-phenoxy-                              101-55-3
# 750   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 751   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 752   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 753   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 754   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 755   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 756   endosulfan sulfate                                       1031-07-8
# 757   endosulfan sulfate                                       1031-07-8
# 758   endosulfan sulfate                                       1031-07-8
# 759   endosulfan sulfate                                       1031-07-8
# 760   endosulfan sulfate                                       1031-07-8
# 761   endosulfan sulfate                                       1031-07-8
# 762   endosulfan sulfate                                       1031-07-8
# 763   endosulfan sulfate                                       1031-07-8
# 764   endosulfan sulfate                                       1031-07-8
# 765   endosulfan sulfate                                       1031-07-8
# 766   endosulfan sulfate                                       1031-07-8
# 767   endosulfan sulfate                                       1031-07-8
# 768   endosulfan sulfate                                       1031-07-8
# 769   endosulfan sulfate                                       1031-07-8
# 770   endosulfan sulfate                                       1031-07-8
# 771   endosulfan sulfate                                       1031-07-8
# 772   endosulfan sulfate                                       1031-07-8
# 773   endosulfan sulfate                                       1031-07-8
# 774   endosulfan sulfate                                       1031-07-8
# 775   endosulfan sulfate                                       1031-07-8
# 776   decabromodiphenyl ether (PBDE209)                        1163-19-5
# 777   decabromodiphenyl ether (PBDE209)                        1163-19-5
# ...                                 ...                              ...
# 5365  length (min) (in combination with matrx)                 -9
# 5366  dry weight percent                                       -9
# 5367  length (max) (in combination with matrx)                 -9
# 5368  length (mean or individual) (in combination with matrx)  -9
# 5369  length (min) (in combination with matrx)                 -9
# 5370  dry weight percent                                       -9
# 5371  dry weight percent                                       -9
# 5372  extractable lipid percent                                -9
# 5373  extractable lipid percent                                -9
# 5374  fat weight percent                                       -9
# 5375  fat weight percent                                       -9
# 5376  length (max) (in combination with matrx)                 -9
# 5377  length (max) (in combination with matrx)                 -9
# 5378  length (mean or individual) (in combination with matrx)  -9
# 5379  length (mean or individual) (in combination with matrx)  -9
# 5380  length (min) (in combination with matrx)                 -9
# 5381  length (min) (in combination with matrx)                 -9
# 5382  weight (mean or individual) (in combination with matrx)  -9
# 5383  weight (mean or individual) (in combination with matrx)  -9
# 5384  dry weight percent                                       -9
# 5385  dry weight percent                                       -9
# 5386  dry weight percent                                       -9
# 5387  fat weight percent                                       -9
# 5388  length (max) (in combination with matrx)                 -9
# 5389  length (mean or individual) (in combination with matrx)  -9
# 5390  length (min) (in combination with matrx)                 -9
# 5391  % female population                                      -9
# 5392  % male population                                        -9
# 5393  % sterile females (IMPS 5-6, INTS 2 or above)            -9
# 5394  perfluorooctylsulfonate acid amide                       NV
#
#      DTYPE       PARAM MUNIT MATRX BASIS METPT METOA  \
# 748   CF    BDE1        -9    SB    W     -9    -9
# 749   CF    BDE3        -9    SB    W     -9    -9
# 750   CF    HCEPC       -9    SB    W     -9    -9
# 751   CF    HCEPC       -9    SB    W     -9    -9
# 752   CF    HCEPC       -9    SB    W     -9    -9
# 753   CF    HCEPC       -9    SB    W     -9    -9
# 754   CF    HCEPC       -9    SB    W     -9    -9
# 755   CF    HCEPC       -9    SB    W     -9    -9
# 756   CF    ENDS        -9    SB    W     -9    -9
# 757   CF    ENDS        -9    MU    W     -9    -9
# 758   CF    ENDS        -9    MU    W     -9    -9
# 759   CF    ENDS        -9    MU    W     -9    -9
# 760   CF    ENDS        -9    MU    W     -9    -9
# 761   CF    ENDS        -9    MU    W     -9    -9
# 762   CF    ENDS        -9    MU    W     -9    -9
# 763   CF    ENDS        -9    MU    W     -9    -9
# 764   CF    ENDS        -9    SB    W     -9    -9
# 765   CF    ENDS        -9    SB    W     -9    -9
# 766   CF    ENDS        -9    SB    W     -9    -9
# 767   CF    ENDS        -9    MU    W     -9    -9
# 768   CF    ENDS        -9    MU    W     -9    -9
# 769   CF    ENDS        -9    MU    W     -9    -9
# 770   CF    ENDS        -9    MU    W     -9    -9
# 771   CF    ENDS        -9    MU    W     -9    -9
# 772   CF    ENDS        -9    MU    W     -9    -9
# 773   CF    ENDS        -9    MU    W     -9    -9
# 774   CF    ENDS        -9    MU    W     -9    -9
# 775   CF    ENDS        -9    SB    W     -9    -9
# 776   CF    BD209       -9    SB    W     -9    -9
# 777   CF    BD209       -9    SB    W     -9    -9
# ...   ..      ...       ..    ..   ..     ..    ..
# 5365  CF    LNMIN       -9    WO    -9    -9    -9
# 5366  CF    DRYWT%      -9    SB    W     -9    -9
# 5367  CF    LNMAX       -9    SH    -9    -9    -9
# 5368  CF    LNMEA       -9    SH    -9    -9    -9
# 5369  CF    LNMIN       -9    SH    -9    -9    -9
# 5370  CF    DRYWT%      -9    SB    -9    -9    -9
# 5371  CF    DRYWT%      -9    SB    W     -9    -9
# 5372  CF    EXLIP%      -9    SB    -9    -9    -9
# 5373  CF    EXLIP%      -9    SB    W     -9    -9
# 5374  CF    FATWT%      -9    SB    -9    -9    -9
# 5375  CF    FATWT%      -9    SB    W     -9    -9
# 5376  CF    LNMAX       -9    SH    -9    -9    -9
# 5377  CF    LNMAX       -9    WO    -9    -9    -9
# 5378  CF    LNMEA       -9    SH    -9    -9    -9
# 5379  CF    LNMEA       -9    WO    -9    -9    -9
# 5380  CF    LNMIN       -9    SH    -9    -9    -9
# 5381  CF    LNMIN       -9    WO    -9    -9    -9
# 5382  CF    WTMEA       -9    EX    -9    -9    -9
# 5383  CF    WTMEA       -9    SB    -9    -9    -9
# 5384  CF    DRYWT%      -9    MU    -9    -9    -9
# 5385  CF    DRYWT%      -9    MU    W     -9    -9
# 5386  CF    DRYWT%      -9    TM    W     -9    -9
# 5387  CF    FATWT%      -9    TM    W     -9    -9
# 5388  CF    LNMAX       -9    WO    -9    -9    -9
# 5389  CF    LNMEA       -9    WO    -9    -9    -9
# 5390  CF    LNMIN       -9    WO    -9    -9    -9
# 5391  CF    %FEMALEPOP  -9    SB    W     -9    -9
# 5392  CF    %MALEPOP    -9    SB    W     -9    -9
# 5393  CF    %STERF      -9    SB    W     -9    -9
# 5394  CF    PFOSA       -9    SB    W     -9    -9
#
#                        Species  AphiaID        Note S06_label      S07_label  \
# 748   Mytilus edulis            140480   Mollusca              not specified
# 749   Mytilus edulis            140480   Mollusca              not specified
# 750   Ostrea edulis             140658   Mollusca              not specified
# 751   Venerupis philippinarum   231750   Mollusca              not specified
# 752   Cerastoderma edule        138998   Mollusca              not specified
# 753   Crassostrea gigas         140656   Mollusca              not specified
# 754   Ensis siliqua             140735   Mollusca              not specified
# 755   Mytilus edulis            140480   Mollusca              not specified
# 756   Ostrea edulis             140658   Mollusca              not specified
# 757   Palaemon serratus         107616   Crustacean            not specified
# 758   Pleuronectes platessa     127143   Fish                  not specified
# 759   Psetta maxima             127149   Fish                  not specified
# 760   Scomber scombrus          127023   Fish                  not specified
# 761   Scophthalmus rhombus      127150   Fish                  not specified
# 762   Thunnus alalunga          127026   Fish                  not specified
# 763   Zeus faber                127427   Fish                  not specified
# 764   Cerastoderma edule        138998   Mollusca              not specified
# 765   Crassostrea gigas         140656   Mollusca              not specified
# 766   Ensis siliqua             140735   Mollusca              not specified
# 767   Gadus morhua              126436   Fish                  not specified
# 768   Loligo vulgaris           140271   Mollusca              not specified
# 769   Lophius budegassa         126554   Fish                  not specified
# 770   Melanogrammus aeglefinus  126437   Fish                  not specified
# 771   Merlangius merlangus      126438   Fish                  not specified
# 772   Merluccius merluccius     126484   Fish                  not specified
# 773   Microstomus kitt          127140   Fish                  not specified
# 774   Molva molva               126461   Fish                  not specified
# 775   Mytilus edulis            140480   Mollusca              not specified
# 776   Ostrea edulis             140658   Mollusca              not specified
# 777   Mytilus edulis            140480   Mollusca              not specified
# ...              ...               ...        ...   ..                   ...
# 5365  Mullus barbatus           126985   Fish                  not specified
# 5366  Mya truncata              140431   Mollusca              not specified
# 5367  Mya truncata              140431   Mollusca              not specified
# 5368  Mya truncata              140431   Mollusca              not specified
# 5369  Mya truncata              140431   Mollusca              not specified
# 5370  Mytilus edulis            140480   Mollusca              not specified
# 5371  Mytilus edulis            140480   Mollusca              not specified
# 5372  Mytilus edulis            140480   Mollusca              not specified
# 5373  Mytilus edulis            140480   Mollusca              not specified
# 5374  Mytilus edulis            140480   Mollusca              not specified
# 5375  Mytilus edulis            140480   Mollusca              not specified
# 5376  Mytilus edulis            140480   Mollusca              not specified
# 5377  Mytilus edulis            140480   Mollusca              not specified
# 5378  Mytilus edulis            140480   Mollusca              not specified
# 5379  Mytilus edulis            140480   Mollusca              not specified
# 5380  Mytilus edulis            140480   Mollusca              not specified
# 5381  Mytilus edulis            140480   Mollusca              not specified
# 5382  Mytilus edulis            140480   Mollusca              not specified
# 5383  Mytilus edulis            140480   Mollusca              not specified
# 5384  Nephrops norvegicus       107254   Crustacean            not specified
# 5385  Nephrops norvegicus       107254   Crustacean            not specified
# 5386  Nephrops norvegicus       107254   Crustacean            not specified
# 5387  Nephrops norvegicus       107254   Crustacean            not specified
# 5388  Nephrops norvegicus       107254   Crustacean            not specified
# 5389  Nephrops norvegicus       107254   Crustacean            not specified
# 5390  Nephrops norvegicus       107254   Crustacean            not specified
# 5391  Nucella lapillus          140403   Mollusca              not specified
# 5392  Nucella lapillus          140403   Mollusca              not specified
# 5393  Nucella lapillus          140403   Mollusca              not specified
# 5394  Mytilus edulis            140480   Mollusca              not specified
#
#                      S27_label S26_label  \
# 748   1-bromo-2-phenoxybenzene  biota
# 749   1-bromo-4-phenoxybenzene  biota
# 750   manual mapping required   biota
# 751   manual mapping required   biota
# 752   manual mapping required   biota
# 753   manual mapping required   biota
# 754   manual mapping required   biota
# 755   manual mapping required   biota
# 756   endosulfan sulfate        biota
# 757   endosulfan sulfate        biota
# 758   endosulfan sulfate        biota
# 759   endosulfan sulfate        biota
# 760   endosulfan sulfate        biota
# 761   endosulfan sulfate        biota
# 762   endosulfan sulfate        biota
# 763   endosulfan sulfate        biota
# 764   endosulfan sulfate        biota
# 765   endosulfan sulfate        biota
# 766   endosulfan sulfate        biota
# 767   endosulfan sulfate        biota
# 768   endosulfan sulfate        biota
# 769   endosulfan sulfate        biota
# 770   endosulfan sulfate        biota
# 771   endosulfan sulfate        biota
# 772   endosulfan sulfate        biota
# 773   endosulfan sulfate        biota
# 774   endosulfan sulfate        biota
# 775   endosulfan sulfate        biota
# 776   decabromodiphenyl ether   biota
# 777   decabromodiphenyl ether   biota
# ...                       ...     ...
# 5365  not applicable            biota
# 5366  not applicable            biota
# 5367  not applicable            biota
# 5368  not applicable            biota
# 5369  not applicable            biota
# 5370  not applicable            biota
# 5371  not applicable            biota
# 5372  not applicable            biota
# 5373  not applicable            biota
# 5374  not applicable            biota
# 5375  not applicable            biota
# 5376  not applicable            biota
# 5377  not applicable            biota
# 5378  not applicable            biota
# 5379  not applicable            biota
# 5380  not applicable            biota
# 5381  not applicable            biota
# 5382  not applicable            biota
# 5383  not applicable            biota
# 5384  not applicable            biota
# 5385  not applicable            biota
# 5386  not applicable            biota
# 5387  not applicable            biota
# 5388  not applicable            biota
# 5389  not applicable            biota
# 5390  not applicable            biota
# 5391  not applicable            biota
# 5392  not applicable            biota
# 5393  not applicable            biota
# 5394  manual mapping required   biota
#
#                                                       TAXON
# 748   Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 749   Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 750   Ostrea edulis (ITIS: 79885: WoRMS 140658)
# 751   Ruditapes philippinarum (WoRMS 231750)
# 752   Cerastoderma edule (ITIS: 80901: WoRMS 138998)
# 753   Crassostrea gigas (ITIS: 79868: WoRMS 140656)
# 754   Ensis siliqua (ITIS: 81026: WoRMS 140735)
# 755   Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 756   Ostrea edulis (ITIS: 79885: WoRMS 140658)
# 757   Palaemon serratus (ITIS: 96451: WoRMS 107616)
# 758   Pleuronectes platessa (ITIS: 172902: WoRMS 127143)
# 759   Scophthalmus maximus (ITIS: 172748: WoRMS 127149)
# 760   Scomber scombrus (ITIS: 172414: WoRMS 127023)
# 761   Scophthalmus rhombus (ITIS: 172749: WoRMS 127150)
# 762   Thunnus alalunga (ITIS: 172419: WoRMS 127026)
# 763   Zeus faber (ITIS: 166287: WoRMS 127427)
# 764   Cerastoderma edule (ITIS: 80901: WoRMS 138998)
# 765   Crassostrea gigas (ITIS: 79868: WoRMS 140656)
# 766   Ensis siliqua (ITIS: 81026: WoRMS 140735)
# 767   Gadus morhua (ITIS: 164712: WoRMS 126436)
# 768   Loligo vulgaris (ITIS: 82375: WoRMS 140271)
# 769   Lophius budegassa (ITIS: 164502: WoRMS 126554)
# 770   Melanogrammus aeglefinus (ITIS: 164744: WoRMS 126437)
# 771   Merlangius merlangus (ITIS: 164758: WoRMS 126438)
# 772   Merluccius merluccius (ITIS: 164795: WoRMS 126484)
# 773   Microstomus kitt (ITIS: 172888: WoRMS 127140)
# 774   Molva molva (ITIS: 164760: WoRMS 126461)
# 775   Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 776   Ostrea edulis (ITIS: 79885: WoRMS 140658)
# 777   Mytilus edulis (ITIS: 79454: WoRMS 140480)
# ...                                          ...
# 5365  Mullus barbatus (ITIS: 169419: WoRMS 126985)
# 5366  Mya truncata (ITIS: 81694: WoRMS 140431)
# 5367  Mya truncata (ITIS: 81694: WoRMS 140431)
# 5368  Mya truncata (ITIS: 81694: WoRMS 140431)
# 5369  Mya truncata (ITIS: 81694: WoRMS 140431)
# 5370  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5371  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5372  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5373  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5374  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5375  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5376  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5377  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5378  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5379  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5380  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5381  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5382  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5383  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5384  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5385  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5386  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5387  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5388  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5389  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5390  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5391  Nucella lapillus (ITIS: 73297: WoRMS 140403)
# 5392  Nucella lapillus (ITIS: 73297: WoRMS 140403)
# 5393  Nucella lapillus (ITIS: 73297: WoRMS 140403)
# 5394  Mytilus edulis (ITIS: 79454: WoRMS 140480)
#
# [4647 rows x 17 columns]

# %% [markdown]
# #### New entries required in S25 semantic model TAXON vocabulary

# %%
display(taxa_map[taxa_map['TAXON']=='New TAXON required.'])
# Out:
#     AphiaID name_from_AphiaID                TAXON
# 47  159021   Pusa hispida      New TAXON required.
# 98  105882   Raja brachyura    New TAXON required.

# %% [markdown]
# ## Map remaining terms of the P01 semantic model

# %%
param_combo['S02_label'] = pd.Series(dtype='object')

param_combo.loc[(param_combo['BASIS']=='L'),'S06_label'] = 'Lipid-normalised concentration'
param_combo.loc[(param_combo['MUNIT']=='%'),'S06_label'] = 'Proportion'
param_combo.loc[(param_combo['MUNIT'].str.contains('Bq')),'S06_label'] = 'Activity'
param_combo.loc[(param_combo['MUNIT']=='ntu') & (param_combo['PARAM']=='TURB'),'S06_label'] = 'Turbidity'
param_combo.loc[(param_combo['MUNIT'].str.contains('Bq')==False) & (param_combo['MUNIT'].str[-1].isin(['l','g'])),'S06_label'] = 'Concentration'

param_combo.loc[(param_combo['MUNIT'].str[-1] == 'l'),'S02_label'] = 'per unit volume of the'
param_combo.loc[(param_combo['MUNIT'].str[-1] == 'g'),'S02_label'] = 'per unit mass of the'
param_combo.loc[(param_combo['BASIS']=='D'),'S02_label'] = 'per unit dry weight of'
param_combo.loc[(param_combo['BASIS']=='W'),'S02_label'] = 'per unit wet weight of'
param_combo.loc[(param_combo['BASIS']=='L'),'S02_label'] = 'in'
param_combo.loc[(param_combo['MUNIT']=='ntu') & (param_combo['PARAM']=='TURB'),'S02_label'] = 'of the'

param_combo.loc[(param_combo['MUNIT']=='-9') & (param_combo['CAS']!='-9') & (param_combo['DTYPE']=='CF') & (param_combo['S06_label']==''),'S06_label'] = 'Concentration'

param_combo['S03_label'] = 'not specified'
param_combo['S04_label'] = 'not specified'
param_combo['S05_label'] = 'not specified'

display(param_combo[(param_combo['DTYPE']=='CF')][['PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Species','AphiaID','Note','S06_label','S07_label','S27_label','S02_label','S26_label','TAXON']])
# Out:
#                                                         PRNAM         CAS  \
# 748   Benzene, 1-bromo-2-phenoxy- (PBDE1)                      7025-06-01
# 749   Benzene, 1-bromo-4-phenoxy-                              101-55-3
# 750   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 751   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 752   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 753   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 754   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 755   cis-heptachlorepoxide "(alpha)"                          1024-57-3
# 756   endosulfan sulfate                                       1031-07-8
# 757   endosulfan sulfate                                       1031-07-8
# 758   endosulfan sulfate                                       1031-07-8
# 759   endosulfan sulfate                                       1031-07-8
# 760   endosulfan sulfate                                       1031-07-8
# 761   endosulfan sulfate                                       1031-07-8
# 762   endosulfan sulfate                                       1031-07-8
# 763   endosulfan sulfate                                       1031-07-8
# 764   endosulfan sulfate                                       1031-07-8
# 765   endosulfan sulfate                                       1031-07-8
# 766   endosulfan sulfate                                       1031-07-8
# 767   endosulfan sulfate                                       1031-07-8
# 768   endosulfan sulfate                                       1031-07-8
# 769   endosulfan sulfate                                       1031-07-8
# 770   endosulfan sulfate                                       1031-07-8
# 771   endosulfan sulfate                                       1031-07-8
# 772   endosulfan sulfate                                       1031-07-8
# 773   endosulfan sulfate                                       1031-07-8
# 774   endosulfan sulfate                                       1031-07-8
# 775   endosulfan sulfate                                       1031-07-8
# 776   decabromodiphenyl ether (PBDE209)                        1163-19-5
# 777   decabromodiphenyl ether (PBDE209)                        1163-19-5
# ...                                 ...                              ...
# 5365  length (min) (in combination with matrx)                 -9
# 5366  dry weight percent                                       -9
# 5367  length (max) (in combination with matrx)                 -9
# 5368  length (mean or individual) (in combination with matrx)  -9
# 5369  length (min) (in combination with matrx)                 -9
# 5370  dry weight percent                                       -9
# 5371  dry weight percent                                       -9
# 5372  extractable lipid percent                                -9
# 5373  extractable lipid percent                                -9
# 5374  fat weight percent                                       -9
# 5375  fat weight percent                                       -9
# 5376  length (max) (in combination with matrx)                 -9
# 5377  length (max) (in combination with matrx)                 -9
# 5378  length (mean or individual) (in combination with matrx)  -9
# 5379  length (mean or individual) (in combination with matrx)  -9
# 5380  length (min) (in combination with matrx)                 -9
# 5381  length (min) (in combination with matrx)                 -9
# 5382  weight (mean or individual) (in combination with matrx)  -9
# 5383  weight (mean or individual) (in combination with matrx)  -9
# 5384  dry weight percent                                       -9
# 5385  dry weight percent                                       -9
# 5386  dry weight percent                                       -9
# 5387  fat weight percent                                       -9
# 5388  length (max) (in combination with matrx)                 -9
# 5389  length (mean or individual) (in combination with matrx)  -9
# 5390  length (min) (in combination with matrx)                 -9
# 5391  % female population                                      -9
# 5392  % male population                                        -9
# 5393  % sterile females (IMPS 5-6, INTS 2 or above)            -9
# 5394  perfluorooctylsulfonate acid amide                       NV
#
#      DTYPE       PARAM MUNIT MATRX BASIS METPT METOA  \
# 748   CF    BDE1        -9    SB    W     -9    -9
# 749   CF    BDE3        -9    SB    W     -9    -9
# 750   CF    HCEPC       -9    SB    W     -9    -9
# 751   CF    HCEPC       -9    SB    W     -9    -9
# 752   CF    HCEPC       -9    SB    W     -9    -9
# 753   CF    HCEPC       -9    SB    W     -9    -9
# 754   CF    HCEPC       -9    SB    W     -9    -9
# 755   CF    HCEPC       -9    SB    W     -9    -9
# 756   CF    ENDS        -9    SB    W     -9    -9
# 757   CF    ENDS        -9    MU    W     -9    -9
# 758   CF    ENDS        -9    MU    W     -9    -9
# 759   CF    ENDS        -9    MU    W     -9    -9
# 760   CF    ENDS        -9    MU    W     -9    -9
# 761   CF    ENDS        -9    MU    W     -9    -9
# 762   CF    ENDS        -9    MU    W     -9    -9
# 763   CF    ENDS        -9    MU    W     -9    -9
# 764   CF    ENDS        -9    SB    W     -9    -9
# 765   CF    ENDS        -9    SB    W     -9    -9
# 766   CF    ENDS        -9    SB    W     -9    -9
# 767   CF    ENDS        -9    MU    W     -9    -9
# 768   CF    ENDS        -9    MU    W     -9    -9
# 769   CF    ENDS        -9    MU    W     -9    -9
# 770   CF    ENDS        -9    MU    W     -9    -9
# 771   CF    ENDS        -9    MU    W     -9    -9
# 772   CF    ENDS        -9    MU    W     -9    -9
# 773   CF    ENDS        -9    MU    W     -9    -9
# 774   CF    ENDS        -9    MU    W     -9    -9
# 775   CF    ENDS        -9    SB    W     -9    -9
# 776   CF    BD209       -9    SB    W     -9    -9
# 777   CF    BD209       -9    SB    W     -9    -9
# ...   ..      ...       ..    ..   ..     ..    ..
# 5365  CF    LNMIN       -9    WO    -9    -9    -9
# 5366  CF    DRYWT%      -9    SB    W     -9    -9
# 5367  CF    LNMAX       -9    SH    -9    -9    -9
# 5368  CF    LNMEA       -9    SH    -9    -9    -9
# 5369  CF    LNMIN       -9    SH    -9    -9    -9
# 5370  CF    DRYWT%      -9    SB    -9    -9    -9
# 5371  CF    DRYWT%      -9    SB    W     -9    -9
# 5372  CF    EXLIP%      -9    SB    -9    -9    -9
# 5373  CF    EXLIP%      -9    SB    W     -9    -9
# 5374  CF    FATWT%      -9    SB    -9    -9    -9
# 5375  CF    FATWT%      -9    SB    W     -9    -9
# 5376  CF    LNMAX       -9    SH    -9    -9    -9
# 5377  CF    LNMAX       -9    WO    -9    -9    -9
# 5378  CF    LNMEA       -9    SH    -9    -9    -9
# 5379  CF    LNMEA       -9    WO    -9    -9    -9
# 5380  CF    LNMIN       -9    SH    -9    -9    -9
# 5381  CF    LNMIN       -9    WO    -9    -9    -9
# 5382  CF    WTMEA       -9    EX    -9    -9    -9
# 5383  CF    WTMEA       -9    SB    -9    -9    -9
# 5384  CF    DRYWT%      -9    MU    -9    -9    -9
# 5385  CF    DRYWT%      -9    MU    W     -9    -9
# 5386  CF    DRYWT%      -9    TM    W     -9    -9
# 5387  CF    FATWT%      -9    TM    W     -9    -9
# 5388  CF    LNMAX       -9    WO    -9    -9    -9
# 5389  CF    LNMEA       -9    WO    -9    -9    -9
# 5390  CF    LNMIN       -9    WO    -9    -9    -9
# 5391  CF    %FEMALEPOP  -9    SB    W     -9    -9
# 5392  CF    %MALEPOP    -9    SB    W     -9    -9
# 5393  CF    %STERF      -9    SB    W     -9    -9
# 5394  CF    PFOSA       -9    SB    W     -9    -9
#
#                        Species  AphiaID        Note      S06_label  \
# 748   Mytilus edulis            140480   Mollusca    Concentration
# 749   Mytilus edulis            140480   Mollusca    Concentration
# 750   Ostrea edulis             140658   Mollusca    Concentration
# 751   Venerupis philippinarum   231750   Mollusca    Concentration
# 752   Cerastoderma edule        138998   Mollusca    Concentration
# 753   Crassostrea gigas         140656   Mollusca    Concentration
# 754   Ensis siliqua             140735   Mollusca    Concentration
# 755   Mytilus edulis            140480   Mollusca    Concentration
# 756   Ostrea edulis             140658   Mollusca    Concentration
# 757   Palaemon serratus         107616   Crustacean  Concentration
# 758   Pleuronectes platessa     127143   Fish        Concentration
# 759   Psetta maxima             127149   Fish        Concentration
# 760   Scomber scombrus          127023   Fish        Concentration
# 761   Scophthalmus rhombus      127150   Fish        Concentration
# 762   Thunnus alalunga          127026   Fish        Concentration
# 763   Zeus faber                127427   Fish        Concentration
# 764   Cerastoderma edule        138998   Mollusca    Concentration
# 765   Crassostrea gigas         140656   Mollusca    Concentration
# 766   Ensis siliqua             140735   Mollusca    Concentration
# 767   Gadus morhua              126436   Fish        Concentration
# 768   Loligo vulgaris           140271   Mollusca    Concentration
# 769   Lophius budegassa         126554   Fish        Concentration
# 770   Melanogrammus aeglefinus  126437   Fish        Concentration
# 771   Merlangius merlangus      126438   Fish        Concentration
# 772   Merluccius merluccius     126484   Fish        Concentration
# 773   Microstomus kitt          127140   Fish        Concentration
# 774   Molva molva               126461   Fish        Concentration
# 775   Mytilus edulis            140480   Mollusca    Concentration
# 776   Ostrea edulis             140658   Mollusca    Concentration
# 777   Mytilus edulis            140480   Mollusca    Concentration
# ...              ...               ...        ...              ...
# 5365  Mullus barbatus           126985   Fish
# 5366  Mya truncata              140431   Mollusca
# 5367  Mya truncata              140431   Mollusca
# 5368  Mya truncata              140431   Mollusca
# 5369  Mya truncata              140431   Mollusca
# 5370  Mytilus edulis            140480   Mollusca
# 5371  Mytilus edulis            140480   Mollusca
# 5372  Mytilus edulis            140480   Mollusca
# 5373  Mytilus edulis            140480   Mollusca
# 5374  Mytilus edulis            140480   Mollusca
# 5375  Mytilus edulis            140480   Mollusca
# 5376  Mytilus edulis            140480   Mollusca
# 5377  Mytilus edulis            140480   Mollusca
# 5378  Mytilus edulis            140480   Mollusca
# 5379  Mytilus edulis            140480   Mollusca
# 5380  Mytilus edulis            140480   Mollusca
# 5381  Mytilus edulis            140480   Mollusca
# 5382  Mytilus edulis            140480   Mollusca
# 5383  Mytilus edulis            140480   Mollusca
# 5384  Nephrops norvegicus       107254   Crustacean
# 5385  Nephrops norvegicus       107254   Crustacean
# 5386  Nephrops norvegicus       107254   Crustacean
# 5387  Nephrops norvegicus       107254   Crustacean
# 5388  Nephrops norvegicus       107254   Crustacean
# 5389  Nephrops norvegicus       107254   Crustacean
# 5390  Nephrops norvegicus       107254   Crustacean
# 5391  Nucella lapillus          140403   Mollusca
# 5392  Nucella lapillus          140403   Mollusca
# 5393  Nucella lapillus          140403   Mollusca
# 5394  Mytilus edulis            140480   Mollusca    Concentration
#
#           S07_label                 S27_label               S02_label  \
# 748   not specified  1-bromo-2-phenoxybenzene  per unit wet weight of
# 749   not specified  1-bromo-4-phenoxybenzene  per unit wet weight of
# 750   not specified  manual mapping required   per unit wet weight of
# 751   not specified  manual mapping required   per unit wet weight of
# 752   not specified  manual mapping required   per unit wet weight of
# 753   not specified  manual mapping required   per unit wet weight of
# 754   not specified  manual mapping required   per unit wet weight of
# 755   not specified  manual mapping required   per unit wet weight of
# 756   not specified  endosulfan sulfate        per unit wet weight of
# 757   not specified  endosulfan sulfate        per unit wet weight of
# 758   not specified  endosulfan sulfate        per unit wet weight of
# 759   not specified  endosulfan sulfate        per unit wet weight of
# 760   not specified  endosulfan sulfate        per unit wet weight of
# 761   not specified  endosulfan sulfate        per unit wet weight of
# 762   not specified  endosulfan sulfate        per unit wet weight of
# 763   not specified  endosulfan sulfate        per unit wet weight of
# 764   not specified  endosulfan sulfate        per unit wet weight of
# 765   not specified  endosulfan sulfate        per unit wet weight of
# 766   not specified  endosulfan sulfate        per unit wet weight of
# 767   not specified  endosulfan sulfate        per unit wet weight of
# 768   not specified  endosulfan sulfate        per unit wet weight of
# 769   not specified  endosulfan sulfate        per unit wet weight of
# 770   not specified  endosulfan sulfate        per unit wet weight of
# 771   not specified  endosulfan sulfate        per unit wet weight of
# 772   not specified  endosulfan sulfate        per unit wet weight of
# 773   not specified  endosulfan sulfate        per unit wet weight of
# 774   not specified  endosulfan sulfate        per unit wet weight of
# 775   not specified  endosulfan sulfate        per unit wet weight of
# 776   not specified  decabromodiphenyl ether   per unit wet weight of
# 777   not specified  decabromodiphenyl ether   per unit wet weight of
# ...             ...                      ...                      ...
# 5365  not specified  not applicable            NaN
# 5366  not specified  not applicable            per unit wet weight of
# 5367  not specified  not applicable            NaN
# 5368  not specified  not applicable            NaN
# 5369  not specified  not applicable            NaN
# 5370  not specified  not applicable            NaN
# 5371  not specified  not applicable            per unit wet weight of
# 5372  not specified  not applicable            NaN
# 5373  not specified  not applicable            per unit wet weight of
# 5374  not specified  not applicable            NaN
# 5375  not specified  not applicable            per unit wet weight of
# 5376  not specified  not applicable            NaN
# 5377  not specified  not applicable            NaN
# 5378  not specified  not applicable            NaN
# 5379  not specified  not applicable            NaN
# 5380  not specified  not applicable            NaN
# 5381  not specified  not applicable            NaN
# 5382  not specified  not applicable            NaN
# 5383  not specified  not applicable            NaN
# 5384  not specified  not applicable            NaN
# 5385  not specified  not applicable            per unit wet weight of
# 5386  not specified  not applicable            per unit wet weight of
# 5387  not specified  not applicable            per unit wet weight of
# 5388  not specified  not applicable            NaN
# 5389  not specified  not applicable            NaN
# 5390  not specified  not applicable            NaN
# 5391  not specified  not applicable            per unit wet weight of
# 5392  not specified  not applicable            per unit wet weight of
# 5393  not specified  not applicable            per unit wet weight of
# 5394  not specified  manual mapping required   per unit wet weight of
#
#      S26_label                                                  TAXON
# 748   biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 749   biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 750   biota     Ostrea edulis (ITIS: 79885: WoRMS 140658)
# 751   biota     Ruditapes philippinarum (WoRMS 231750)
# 752   biota     Cerastoderma edule (ITIS: 80901: WoRMS 138998)
# 753   biota     Crassostrea gigas (ITIS: 79868: WoRMS 140656)
# 754   biota     Ensis siliqua (ITIS: 81026: WoRMS 140735)
# 755   biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 756   biota     Ostrea edulis (ITIS: 79885: WoRMS 140658)
# 757   biota     Palaemon serratus (ITIS: 96451: WoRMS 107616)
# 758   biota     Pleuronectes platessa (ITIS: 172902: WoRMS 127143)
# 759   biota     Scophthalmus maximus (ITIS: 172748: WoRMS 127149)
# 760   biota     Scomber scombrus (ITIS: 172414: WoRMS 127023)
# 761   biota     Scophthalmus rhombus (ITIS: 172749: WoRMS 127150)
# 762   biota     Thunnus alalunga (ITIS: 172419: WoRMS 127026)
# 763   biota     Zeus faber (ITIS: 166287: WoRMS 127427)
# 764   biota     Cerastoderma edule (ITIS: 80901: WoRMS 138998)
# 765   biota     Crassostrea gigas (ITIS: 79868: WoRMS 140656)
# 766   biota     Ensis siliqua (ITIS: 81026: WoRMS 140735)
# 767   biota     Gadus morhua (ITIS: 164712: WoRMS 126436)
# 768   biota     Loligo vulgaris (ITIS: 82375: WoRMS 140271)
# 769   biota     Lophius budegassa (ITIS: 164502: WoRMS 126554)
# 770   biota     Melanogrammus aeglefinus (ITIS: 164744: WoRMS 126437)
# 771   biota     Merlangius merlangus (ITIS: 164758: WoRMS 126438)
# 772   biota     Merluccius merluccius (ITIS: 164795: WoRMS 126484)
# 773   biota     Microstomus kitt (ITIS: 172888: WoRMS 127140)
# 774   biota     Molva molva (ITIS: 164760: WoRMS 126461)
# 775   biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 776   biota     Ostrea edulis (ITIS: 79885: WoRMS 140658)
# 777   biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# ...     ...                                            ...
# 5365  biota     Mullus barbatus (ITIS: 169419: WoRMS 126985)
# 5366  biota     Mya truncata (ITIS: 81694: WoRMS 140431)
# 5367  biota     Mya truncata (ITIS: 81694: WoRMS 140431)
# 5368  biota     Mya truncata (ITIS: 81694: WoRMS 140431)
# 5369  biota     Mya truncata (ITIS: 81694: WoRMS 140431)
# 5370  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5371  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5372  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5373  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5374  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5375  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5376  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5377  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5378  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5379  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5380  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5381  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5382  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5383  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5384  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5385  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5386  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5387  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5388  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5389  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5390  biota     Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5391  biota     Nucella lapillus (ITIS: 73297: WoRMS 140403)
# 5392  biota     Nucella lapillus (ITIS: 73297: WoRMS 140403)
# 5393  biota     Nucella lapillus (ITIS: 73297: WoRMS 140403)
# 5394  biota     Mytilus edulis (ITIS: 79454: WoRMS 140480)
#
# [4647 rows x 18 columns]

# %% [markdown]
# ## Map matrix of the biota to appropriate NVS S25 SUBCOMPONENT and/or STAGE. Note some constraints based on taxa type applied in the code.

# %%
param_combo['SIZE'] = pd.Series(dtype='object')
param_combo['SEX'] = pd.Series(dtype='object')
param_combo['STAGE'] = pd.Series(dtype='object')
param_combo['SUBCOMPONENT'] = pd.Series(dtype='object')
param_combo['SUBGROUP'] = pd.Series(dtype='object')
param_combo['MORPHOLOGY'] = pd.Series(dtype='object')
param_combo['COLOUR'] = pd.Series(dtype='object')

# Direct 1-2-1 mappings
param_combo.loc[param_combo['MATRX'] == 'WO','SUBCOMPONENT'] = 'not specified'
param_combo.loc[param_combo['MATRX'] == 'TM','SUBCOMPONENT'] = 'muscle tissue'
param_combo.loc[param_combo['MATRX'] == 'SI','SUBCOMPONENT'] = 'not specified'
param_combo.loc[param_combo['MATRX'] == 'SH','SUBCOMPONENT'] = 'shell'
param_combo.loc[param_combo['MATRX'] == 'MU&EP','SUBCOMPONENT'] = 'muscle tissues and skin'
param_combo.loc[param_combo['MATRX'] == 'LI','SUBCOMPONENT'] = 'liver'
param_combo.loc[param_combo['MATRX'] == 'KI','SUBCOMPONENT'] = 'kidney'
param_combo.loc[param_combo['MATRX'] == 'GO','SUBCOMPONENT'] = 'gonads'
param_combo.loc[param_combo['MATRX'] == 'GI','SUBCOMPONENT'] = 'gill'
param_combo.loc[param_combo['MATRX'] == 'FE','SUBCOMPONENT'] = 'feathers'
param_combo.loc[param_combo['MATRX'] == 'FA','SUBCOMPONENT'] = 'body fat'                                             
param_combo.loc[param_combo['MATRX'] == 'EP','SUBCOMPONENT'] = 'skin'
param_combo.loc[param_combo['MATRX'] == 'BS','SUBCOMPONENT'] = 'blood serum'
param_combo.loc[param_combo['MATRX'] == 'BR','SUBCOMPONENT'] = 'brain'
param_combo.loc[param_combo['MATRX'] == 'BL','SUBCOMPONENT'] = 'blood'
param_combo.loc[param_combo['MATRX'] == 'BC','SUBCOMPONENT'] = 'blood cells'
                                                 
param_combo.loc[param_combo['MATRX'].isin(['EG','EH','RO']),'STAGE'] = 'eggs'
                                                 
param_combo.loc[param_combo['MATRX'] == 'EH','SUBCOMPONENT'] = 'egg yolk and albumen homogenate'

param_combo.loc[(param_combo['MATRX'] == 'MU') & (param_combo['Species'] == 'Loligo vulgaris'),'SUBCOMPONENT'] = 'flesh'
param_combo.loc[(param_combo['MATRX'] == 'MU') & (param_combo['Species'] != 'Loligo vulgaris'),'SUBCOMPONENT'] = 'muscle tissue'
param_combo.loc[(param_combo['MATRX'] == 'EX') & (param_combo['Species'] == 'Mytilus edulis'),'SUBCOMPONENT'] = 'shell'
param_combo.loc[(param_combo['MATRX'] == 'EX') & (param_combo['Species'] != 'Mytilus edulis'),'SUBCOMPONENT'] ='Checking species-matrx combo validity with ICES.'
param_combo.loc[(param_combo['MATRX'] == 'BB') & (param_combo['Note'] != 'Fish'),'SUBCOMPONENT'] = 'blubber'
param_combo.loc[(param_combo['MATRX'] == 'BB') & (param_combo['Note'] == 'Fish'),'SUBCOMPONENT'] = 'Checking species-matrx combo validity with ICES.'

param_combo.loc[(param_combo['MATRX'] == 'SB') & (param_combo['Species'].isin(['Gobius','Crangon crangon','Mysidacea'])==False),'SUBCOMPONENT'] = 'flesh'
param_combo.loc[(param_combo['MATRX'] == 'SB') & (param_combo['Species'].isin(['Gobius','Crangon crangon','Mysidacea'])),'SUBCOMPONENT'] = 'Checking species-matrx combo validity with ICES.'

# Mark empty SUBCOMPONENT and STAGE cells as 'not specified'
param_combo = param_combo.fillna(value={'SUBCOMPONENT': 'not specified', 
                                        'STAGE': 'not specified',
                                        'COLOUR': 'not specified',
                                        'SUBGROUP': 'not specified',
                                        'SIZE': 'not specified',
                                        'SEX': 'not specified',
                                        'MORPHOLOGY': 'not specified',
                                       }
                                )

display(param_combo[(param_combo['DTYPE']=='CF')][['DTYPE','MATRX','Species','AphiaID','Note','TAXON','SUBCOMPONENT','STAGE','COLOUR','SUBGROUP','SIZE','MORPHOLOGY','SEX']].drop_duplicates().head(20))
# Out:
#     DTYPE MATRX                   Species  AphiaID        Note  \
# 748  CF    SB    Mytilus edulis            140480   Mollusca
# 750  CF    SB    Ostrea edulis             140658   Mollusca
# 751  CF    SB    Venerupis philippinarum   231750   Mollusca
# 752  CF    SB    Cerastoderma edule        138998   Mollusca
# 753  CF    SB    Crassostrea gigas         140656   Mollusca
# 754  CF    SB    Ensis siliqua             140735   Mollusca
# 757  CF    MU    Palaemon serratus         107616   Crustacean
# 758  CF    MU    Pleuronectes platessa     127143   Fish
# 759  CF    MU    Psetta maxima             127149   Fish
# 760  CF    MU    Scomber scombrus          127023   Fish
# 761  CF    MU    Scophthalmus rhombus      127150   Fish
# 762  CF    MU    Thunnus alalunga          127026   Fish
# 763  CF    MU    Zeus faber                127427   Fish
# 767  CF    MU    Gadus morhua              126436   Fish
# 768  CF    MU    Loligo vulgaris           140271   Mollusca
# 769  CF    MU    Lophius budegassa         126554   Fish
# 770  CF    MU    Melanogrammus aeglefinus  126437   Fish
# 771  CF    MU    Merlangius merlangus      126438   Fish
# 772  CF    MU    Merluccius merluccius     126484   Fish
# 773  CF    MU    Microstomus kitt          127140   Fish
#
#                                                      TAXON   SUBCOMPONENT  \
# 748  Mytilus edulis (ITIS: 79454: WoRMS 140480)             flesh
# 750  Ostrea edulis (ITIS: 79885: WoRMS 140658)              flesh
# 751  Ruditapes philippinarum (WoRMS 231750)                 flesh
# 752  Cerastoderma edule (ITIS: 80901: WoRMS 138998)         flesh
# 753  Crassostrea gigas (ITIS: 79868: WoRMS 140656)          flesh
# 754  Ensis siliqua (ITIS: 81026: WoRMS 140735)              flesh
# 757  Palaemon serratus (ITIS: 96451: WoRMS 107616)          muscle tissue
# 758  Pleuronectes platessa (ITIS: 172902: WoRMS 127143)     muscle tissue
# 759  Scophthalmus maximus (ITIS: 172748: WoRMS 127149)      muscle tissue
# 760  Scomber scombrus (ITIS: 172414: WoRMS 127023)          muscle tissue
# 761  Scophthalmus rhombus (ITIS: 172749: WoRMS 127150)      muscle tissue
# 762  Thunnus alalunga (ITIS: 172419: WoRMS 127026)          muscle tissue
# 763  Zeus faber (ITIS: 166287: WoRMS 127427)                muscle tissue
# 767  Gadus morhua (ITIS: 164712: WoRMS 126436)              muscle tissue
# 768  Loligo vulgaris (ITIS: 82375: WoRMS 140271)            flesh
# 769  Lophius budegassa (ITIS: 164502: WoRMS 126554)         muscle tissue
# 770  Melanogrammus aeglefinus (ITIS: 164744: WoRMS 126437)  muscle tissue
# 771  Merlangius merlangus (ITIS: 164758: WoRMS 126438)      muscle tissue
# 772  Merluccius merluccius (ITIS: 164795: WoRMS 126484)     muscle tissue
# 773  Microstomus kitt (ITIS: 172888: WoRMS 127140)          muscle tissue
#
#              STAGE         COLOUR       SUBGROUP           SIZE  \
# 748  not specified  not specified  not specified  not specified
# 750  not specified  not specified  not specified  not specified
# 751  not specified  not specified  not specified  not specified
# 752  not specified  not specified  not specified  not specified
# 753  not specified  not specified  not specified  not specified
# 754  not specified  not specified  not specified  not specified
# 757  not specified  not specified  not specified  not specified
# 758  not specified  not specified  not specified  not specified
# 759  not specified  not specified  not specified  not specified
# 760  not specified  not specified  not specified  not specified
# 761  not specified  not specified  not specified  not specified
# 762  not specified  not specified  not specified  not specified
# 763  not specified  not specified  not specified  not specified
# 767  not specified  not specified  not specified  not specified
# 768  not specified  not specified  not specified  not specified
# 769  not specified  not specified  not specified  not specified
# 770  not specified  not specified  not specified  not specified
# 771  not specified  not specified  not specified  not specified
# 772  not specified  not specified  not specified  not specified
# 773  not specified  not specified  not specified  not specified
#
#         MORPHOLOGY            SEX
# 748  not specified  not specified
# 750  not specified  not specified
# 751  not specified  not specified
# 752  not specified  not specified
# 753  not specified  not specified
# 754  not specified  not specified
# 757  not specified  not specified
# 758  not specified  not specified
# 759  not specified  not specified
# 760  not specified  not specified
# 761  not specified  not specified
# 762  not specified  not specified
# 763  not specified  not specified
# 767  not specified  not specified
# 768  not specified  not specified
# 769  not specified  not specified
# 770  not specified  not specified
# 771  not specified  not specified
# 772  not specified  not specified
# 773  not specified  not specified

# %% [markdown]
# ### Download Biological Entity (S25) semantic model from the NVS

# %%
#%% Get the latest semantic model vocabulary contents from the NVS Sparql endpoint

a1 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0A++++PREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A++++%0D%0A++++select+%3F"
a2 = "+%3F"
a3 = "%0D%0A++++where+%7B%0D%0A++++%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2F"
a4 = "%2Fcurrent%2F%3E+skos%3Amember+%3Furl+.%0D%0A++++%3Furl+skos%3AprefLabel+%3F"
a5 = "+.%0D%0A++++%3Furl+skos%3Anotation+%3Fc+.%0D%0A++++%3Furl+owl%3Adeprecated+%27false%27+.%0D%0A++++BIND%28replace%28str%28%3Fc%29%2C%27SDN%3A"
a6 = "%3A%3A%27%2C%27%27%2C%27i%27%29+AS+%3F"
a7 = "%29%0D%0A++++%7D&output=csv&stylesheet="

S09 = pd.read_csv(a1+'S09'+a2+'S09_label'+a3+'S09'+a4+'S09_label'+a5+'S09'+a6+'S09'+a7)
S10 = pd.read_csv(a1+'S10'+a2+'S10_label'+a3+'S10'+a4+'S10_label'+a5+'S10'+a6+'S10'+a7)
S11 = pd.read_csv(a1+'S11'+a2+'S11_label'+a3+'S11'+a4+'S11_label'+a5+'S11'+a6+'S11'+a7)
S12 = pd.read_csv(a1+'S12'+a2+'S12_label'+a3+'S12'+a4+'S12_label'+a5+'S12'+a6+'S12'+a7)
S13 = pd.read_csv(a1+'S13'+a2+'S13_label'+a3+'S13'+a4+'S13_label'+a5+'S13'+a6+'S13'+a7)
S14 = pd.read_csv(a1+'S14'+a2+'S14_label'+a3+'S14'+a4+'S14_label'+a5+'S14'+a6+'S14'+a7)
S15 = pd.read_csv(a1+'S15'+a2+'S15_label'+a3+'S15'+a4+'S15_label'+a5+'S15'+a6+'S15'+a7)
S25 = pd.read_csv(a1+'S25'+a2+'S25_label'+a3+'S25'+a4+'S25_label'+a5+'S25'+a6+'S25'+a7)

# Download semantic component mapping

urlS09 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS09+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS09%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS09%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS09%29+.%0D%0A%7D&output=csv&stylesheet="
S09_S25 = pd.read_csv(urlS09)
print("S09_S25 mapping downloaded.")

urlS10 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS10+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS10%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS10%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS10%29+.%0D%0A%7D&output=csv&stylesheet="
S10_S25 = pd.read_csv(urlS10)
print("S10_S25 mapping downloaded.")

urlS11 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS11+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS11%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS11%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS11%29+.%0D%0A%7D&output=csv&stylesheet="
S11_S25 = pd.read_csv(urlS11)
print("S11_S25 mapping downloaded.")

urlS12 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS12+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS12%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS12%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS12%29+.%0D%0A%7D&output=csv&stylesheet="
S12_S25 = pd.read_csv(urlS12)
print("S12_S25 mapping downloaded.")

urlS13 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS13+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS13%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS13%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS13%29+.%0D%0A%7D&output=csv&stylesheet="
S13_S25 = pd.read_csv(urlS13)
print("S13_S25 mapping downloaded.")

urlS14 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS14+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS14%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS14%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS14%29+.%0D%0A%7D&output=csv&stylesheet="
S14_S25 = pd.read_csv(urlS14)
print("S14_S25 mapping downloaded.")

urlS15 = "http://vocab.nerc.ac.uk/sparql/sparql?query=PREFIX+skos%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0D%0APREFIX+owl%3A+%3Chttp%3A%2F%2Fwww.w3.org%2F2002%2F07%2Fowl%23%3E%0D%0A%0D%0Aselect+distinct+%3FS15+%3FS25%0D%0Awhere+%7B%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS15%2Fcurrent%2F%3E+skos%3Amember+%3Furla+.%0D%0A%3Furla+owl%3Adeprecated+%27false%27+.%0D%0A%3Furla+skos%3Anotation+%3Fn2+.%0D%0A%3Furla+skos%3Arelated+%3Furlb+.%0D%0A%3Chttp%3A%2F%2Fvocab.nerc.ac.uk%2Fcollection%2FS25%2Fcurrent%2F%3E+skos%3Amember+%3Furlb+.%0D%0A%3Furlb+owl%3Adeprecated+%27false%27+.%0D%0A%3Furlb+skos%3Anotation+%3Fn1+.%0D%0ABIND%28replace%28%3Fn1%2C+%22SDN%3AS25%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS25%29+.%0D%0ABIND%28replace%28%3Fn2%2C+%22SDN%3AS15%3A%3A%22%2C+%22%22%2C+%22i%22%29+AS+%3FS15%29+.%0D%0A%7D&output=csv&stylesheet="
S15_S25 = pd.read_csv(urlS15)
print("S15_S25 mapping downloaded.")

# Build S25 semantic model dataframe
S25 = pd.merge(S25, S09_S25, how='left', on='S25')
S25 = pd.merge(S25, S10_S25, how='left', on='S25')
S25 = pd.merge(S25, S11_S25, how='left', on='S25')
S25 = pd.merge(S25, S12_S25, how='left', on='S25')
S25 = pd.merge(S25, S13_S25, how='left', on='S25')
S25 = pd.merge(S25, S14_S25, how='left', on='S25')
S25 = pd.merge(S25, S15_S25, how='left', on='S25')

S25 = S25.fillna(value={'S09': 'S09133',
                        'S10': 'S104',
                        'S11': 'S1131',
                        'S12': 'S1219',
                        'S13': 'S1319',
                        'S14': 'S1430',
                        'S15': 'S152',
                       }
                )

S25['TAXON'] = S25['S25_label'].str.replace(r" \[.*\]","", regex=True)
print("S25 semantic model dataframe constructed")
# Out:
# S09_S25 mapping downloaded.
# S10_S25 mapping downloaded.
# S11_S25 mapping downloaded.
# S12_S25 mapping downloaded.
# S13_S25 mapping downloaded.
# S14_S25 mapping downloaded.
# S15_S25 mapping downloaded.
# S25 semantic model dataframe constructed

# %%
# Map biological entity labels to vocabulary codes
param_combo = pd.merge(param_combo, S09, how='left', left_on='SIZE', right_on='S09_label').drop(columns=['SIZE'])
param_combo = pd.merge(param_combo, S10, how='left', left_on='SEX', right_on='S10_label').drop(columns=['SEX'])
param_combo = pd.merge(param_combo, S11, how='left', left_on='STAGE', right_on='S11_label').drop(columns=['STAGE'])
param_combo = pd.merge(param_combo, S12, how='left', left_on='SUBCOMPONENT', right_on='S12_label').drop(columns=['SUBCOMPONENT'])
param_combo = pd.merge(param_combo, S13, how='left', left_on='SUBGROUP', right_on='S13_label').drop(columns=['SUBGROUP'])
param_combo = pd.merge(param_combo, S14, how='left', left_on='MORPHOLOGY', right_on='S14_label').drop(columns=['MORPHOLOGY'])
param_combo = pd.merge(param_combo, S15, how='left', left_on='COLOUR', right_on='S15_label').drop(columns=['COLOUR'])

# Map Biological entity semantic model combinations to table combinations

param_combo = pd.merge(param_combo, S25, how='left', on=['TAXON','S09','S10','S11','S12','S13','S14','S15'])

# Reset water and sediment defaults for biological entity
param_combo.loc[param_combo['DTYPE'].isin(['CW','CS']),'S25'] = 'BE007736'
param_combo.loc[param_combo['DTYPE'].isin(['CW','CS']),'S25_label'] = 'not applicable'

S25new = param_combo[(param_combo['DTYPE']=='CF') & (param_combo['S25'].isnull())][['Species','AphiaID','MATRX','S25','S25_label','TAXON','S09_label','S10_label','S11_label','S12_label','S13_label','S14_label','S15_label','S09','S10','S11','S12','S13','S14','S15']].drop_duplicates().sort_values(['Species','MATRX'])

# Save new biological entity combinations
S25new_file = os.path.join(results,'new_S25.csv')
S25new.to_csv(S25new_file, index=False)
print("New biological entity combinations saved to: %s" % taxadis_file)
print("New biological entity combinations: %s" % len(S25new))
# Out:
# New biological entity combinations saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\taxa_discrepancy.csv
# New biological entity combinations: 23

# %%
display(param_combo[(param_combo['DTYPE']=='CF') & (param_combo['S25'].notnull())][['Species','AphiaID','MATRX','S25','S25_label','TAXON','S11_label','S12_label']].drop_duplicates().sort_values(['Species','MATRX']))
# Out:
#                          Species  AphiaID MATRX       S25  \
# 4236  Anarhichas lupus            126758   MU    BE007497
# 5474  Anarhichas lupus            126758   WO    BE008593
# 1033  Anarhichas minor            126759   LI    BE007498
# 4324  Anarhichas minor            126759   MU    BE007499
# 5478  Anarhichas minor            126759   WO    BE008535
# 800   Anguilla anguilla           126281   MU    BE006784
# 5483  Anguilla anguilla           126281   WO    BE000279
# 5484  Anguilla anguilla           126281   WO    BE008901
# 4701  Aphanopus carbo             127085   GI    BE007500
# 4702  Aphanopus carbo             127085   GO    BE007639
# 4703  Aphanopus carbo             127085   LI    BE007502
# 4704  Aphanopus carbo             127085   MU    BE007501
# 4241  Balaenoptera acutorostrata  137087   BA    BE006511
# 803   Balaenoptera acutorostrata  137087   BB    BE008592
# 4242  Balaenoptera acutorostrata  137087   KI    BE008567
# 4243  Balaenoptera acutorostrata  137087   LI    BE008580
# 4244  Balaenoptera acutorostrata  137087   MU    BE008581
# 4709  Bathysaurus ferox           126369   GO    BE007638
# 4710  Bathysaurus ferox           126369   LI    BE007503
# 4711  Bathysaurus ferox           126369   MU    BE007504
# 1382  Boreogadus saida            126433   LI    BE007505
# 4713  Boreogadus saida            126433   MU    BE007506
# 1383  Brosme brosme               126447   LI    BE007507
# 1384  Brosme brosme               126447   MU    BE007508
# 5490  Brosme brosme               126447   WO    BE008536
# 1385  Cancer pagurus              107276   LI    BE008569
# 1386  Cancer pagurus              107276   MU    BE008534
# 4338  Cepphus grylle              137130   FE    BE008519
# 4339  Cepphus grylle              137130   KI    BE008530
# 807   Cepphus grylle              137130   LI    BE008505
# ...              ...                 ...   ..         ...
# 5418  Scomber scombrus            127023   WO    BE005094
# 5419  Scomber scombrus            127023   WO    BE009241
# 762   Scophthalmus rhombus        127150   MU    BE007585
# 5428  Scophthalmus rhombus        127150   WO    BE008571
# 794   Scyliorhinus canicula       105814   MU    BE007587
# 5433  Scyliorhinus canicula       105814   WO    BE008548
# 1502  Sebastes marinus            151324   LI    BE008517
# 1503  Sebastes marinus            151324   MU    BE008508
# 1504  Sebastes mentella           127254   LI    BE007588
# 4812  Sebastes mentella           127254   MU    BE007589
# 795   Solea solea                 127160   MU    BE007591
# 5439  Solea solea                 127160   WO    BE005175
# 4007  Solea vulgaris              154712   LI    BE008502
# 1505  Solea vulgaris              154712   MU    BE008513
# 1507  Solea vulgaris              154712   WO    BE008522
# 844   Somateria mollissima        137074   FA    BE008556
# 845   Somateria mollissima        137074   LI    BE008602
# 1510  Sprattus sprattus           126425   MU    BE007593
# 796   Squalus acanthias           105923   MU    BE007595
# 5448  Squalus acanthias           105923   WO    BE008605
# 763   Thunnus alalunga            127026   MU    BE008503
# 5454  Thunnus alalunga            127026   WO    BE008523
# 4320  Triglidae                   125598   MU    BE007599
# 5458  Triglidae                   125598   WO    BE008559
# 848   Uria lomvia                 137134   LI    BE008525
# 849   Ursus maritimus             137085   BB    BE008504
# 764   Zeus faber                  127427   MU    BE007601
# 5470  Zeus faber                  127427   WO    BE008597
# 850   Zoarces viviparus           127123   LI    BE006622
# 851   Zoarces viviparus           127123   MU    BE006623
#
#                                                                                   S25_label  \
# 4236  Anarhichas lupus (ITIS: 171341: WoRMS 126758) [Subcomponent: muscle tissue]
# 5474  Anarhichas lupus (ITIS: 171341: WoRMS 126758)
# 1033  Anarhichas minor (ITIS: 171342: WoRMS 126759) [Subcomponent: liver]
# 4324  Anarhichas minor (ITIS: 171342: WoRMS 126759) [Subcomponent: muscle tissue]
# 5478  Anarhichas minor (ITIS: 171342: WoRMS 126759)
# 800   Anguilla anguilla (ITIS: 161128: WoRMS 126281) [Subcomponent: muscle tissue]
# 5483  Anguilla anguilla (ITIS: 161128: WoRMS 126281)
# 5484  Anguilla anguilla (ITIS: 161128: WoRMS 126281) [Subcomponent: liver]
# 4701  Aphanopus carbo (ITIS: 172389: WoRMS 127085) [Subcomponent: gill]
# 4702  Aphanopus carbo (ITIS: 172389: WoRMS 127085) [Subcomponent: gonads]
# 4703  Aphanopus carbo (ITIS: 172389: WoRMS 127085) [Subcomponent: liver]
# 4704  Aphanopus carbo (ITIS: 172389: WoRMS 127085) [Subcomponent: muscle tissue]
# 4241  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087)
# 803   Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087) [Subcomponent: blubber]
# 4242  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087) [Subcomponent: kidney]
# 4243  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087) [Subcomponent: liver]
# 4244  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087) [Subcomponent: muscle tissue]
# 4709  Bathysaurus ferox (ITIS: 162782: WoRMS 126369) [Subcomponent: gonads]
# 4710  Bathysaurus ferox (ITIS: 162782: WoRMS 126369) [Subcomponent: liver]
# 4711  Bathysaurus ferox (ITIS: 162782: WoRMS 126369) [Subcomponent: muscle tissue]
# 1382  Boreogadus saida (ITIS: 164706: WoRMS 126433) [Subcomponent: liver]
# 4713  Boreogadus saida (ITIS: 164706: WoRMS 126433) [Subcomponent: muscle tissue]
# 1383  Brosme brosme (ITIS: 164740: WoRMS 126447) [Subcomponent: liver]
# 1384  Brosme brosme (ITIS: 164740: WoRMS 126447) [Subcomponent: muscle tissue]
# 5490  Brosme brosme (ITIS: 164740: WoRMS 126447)
# 1385  Cancer pagurus (ITIS: 98681: WoRMS 107276) [Subcomponent: liver]
# 1386  Cancer pagurus (ITIS: 98681: WoRMS 107276) [Subcomponent: muscle tissue]
# 4338  Cepphus grylle (ITIS: 176985: WoRMS 137130) [Subcomponent: feathers]
# 4339  Cepphus grylle (ITIS: 176985: WoRMS 137130) [Subcomponent: kidney]
# 807   Cepphus grylle (ITIS: 176985: WoRMS 137130) [Subcomponent: liver]
# ...                                                                 ...
# 5418  Scomber scombrus (ITIS: 172414: WoRMS 127023)
# 5419  Scomber scombrus (ITIS: 172414: WoRMS 127023) [Stage: eggs]
# 762   Scophthalmus rhombus (ITIS: 172749: WoRMS 127150) [Subcomponent: muscle tissue]
# 5428  Scophthalmus rhombus (ITIS: 172749: WoRMS 127150)
# 794   Scyliorhinus canicula (ITIS: 160065: WoRMS 105814) [Subcomponent: muscle tissue]
# 5433  Scyliorhinus canicula (ITIS: 160065: WoRMS 105814)
# 1502  Sebastes marinus (ITIS: 166781: WoRMS 151324) [Subcomponent: liver]
# 1503  Sebastes marinus (ITIS: 166781: WoRMS 151324) [Subcomponent: muscle tissue]
# 1504  Sebastes mentella (ITIS: 166756: WoRMS 127254) [Subcomponent: liver]
# 4812  Sebastes mentella (ITIS: 166756: WoRMS 127254) [Subcomponent: muscle tissue]
# 795   Solea solea (ITIS: 173002: WoRMS 127160) [Subcomponent: muscle tissue]
# 5439  Solea solea (ITIS: 173002: WoRMS 127160)
# 4007  Solea vulgaris (ITIS: 173001: WoRMS 154712) [Subcomponent: liver]
# 1505  Solea vulgaris (ITIS: 173001: WoRMS 154712) [Subcomponent: muscle tissue]
# 1507  Solea vulgaris (ITIS: 173001: WoRMS 154712)
# 844   Somateria mollissima (ITIS: 175155: WoRMS 137074) [Subcomponent: body fat]
# 845   Somateria mollissima (ITIS: 175155: WoRMS 137074) [Subcomponent: liver]
# 1510  Sprattus sprattus (ITIS: 161789: WoRMS 126425) [Subcomponent: muscle tissue]
# 796   Squalus acanthias (ITIS: 160617: WoRMS 105923) [Subcomponent: muscle tissue]
# 5448  Squalus acanthias (ITIS: 160617: WoRMS 105923)
# 763   Thunnus alalunga (ITIS: 172419: WoRMS 127026) [Subcomponent: muscle tissue]
# 5454  Thunnus alalunga (ITIS: 172419: WoRMS 127026)
# 4320  Triglidae (ITIS: 166972: WoRMS 125598) [Subcomponent: muscle tissue]
# 5458  Triglidae (ITIS: 166972: WoRMS 125598)
# 848   Uria lomvia (ITIS: 176978: WoRMS 137134) [Subcomponent: liver]
# 849   Ursus maritimus (ITIS: 180542: WoRMS 137085) [Subcomponent: blubber]
# 764   Zeus faber (ITIS: 166287: WoRMS 127427) [Subcomponent: muscle tissue]
# 5470  Zeus faber (ITIS: 166287: WoRMS 127427)
# 850   Zoarces viviparus (ITIS: 165324: WoRMS 127123) [Subcomponent: liver]
# 851   Zoarces viviparus (ITIS: 165324: WoRMS 127123) [Subcomponent: muscle tissue]
#
#                                                         TAXON      S11_label  \
# 4236  Anarhichas lupus (ITIS: 171341: WoRMS 126758)            not specified
# 5474  Anarhichas lupus (ITIS: 171341: WoRMS 126758)            not specified
# 1033  Anarhichas minor (ITIS: 171342: WoRMS 126759)            not specified
# 4324  Anarhichas minor (ITIS: 171342: WoRMS 126759)            not specified
# 5478  Anarhichas minor (ITIS: 171342: WoRMS 126759)            not specified
# 800   Anguilla anguilla (ITIS: 161128: WoRMS 126281)           not specified
# 5483  Anguilla anguilla (ITIS: 161128: WoRMS 126281)           not specified
# 5484  Anguilla anguilla (ITIS: 161128: WoRMS 126281)           not specified
# 4701  Aphanopus carbo (ITIS: 172389: WoRMS 127085)             not specified
# 4702  Aphanopus carbo (ITIS: 172389: WoRMS 127085)             not specified
# 4703  Aphanopus carbo (ITIS: 172389: WoRMS 127085)             not specified
# 4704  Aphanopus carbo (ITIS: 172389: WoRMS 127085)             not specified
# 4241  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087)  not specified
# 803   Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087)  not specified
# 4242  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087)  not specified
# 4243  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087)  not specified
# 4244  Balaenoptera acutorostrata (ITIS: 180524: WoRMS 137087)  not specified
# 4709  Bathysaurus ferox (ITIS: 162782: WoRMS 126369)           not specified
# 4710  Bathysaurus ferox (ITIS: 162782: WoRMS 126369)           not specified
# 4711  Bathysaurus ferox (ITIS: 162782: WoRMS 126369)           not specified
# 1382  Boreogadus saida (ITIS: 164706: WoRMS 126433)            not specified
# 4713  Boreogadus saida (ITIS: 164706: WoRMS 126433)            not specified
# 1383  Brosme brosme (ITIS: 164740: WoRMS 126447)               not specified
# 1384  Brosme brosme (ITIS: 164740: WoRMS 126447)               not specified
# 5490  Brosme brosme (ITIS: 164740: WoRMS 126447)               not specified
# 1385  Cancer pagurus (ITIS: 98681: WoRMS 107276)               not specified
# 1386  Cancer pagurus (ITIS: 98681: WoRMS 107276)               not specified
# 4338  Cepphus grylle (ITIS: 176985: WoRMS 137130)              not specified
# 4339  Cepphus grylle (ITIS: 176985: WoRMS 137130)              not specified
# 807   Cepphus grylle (ITIS: 176985: WoRMS 137130)              not specified
# ...                                           ...                        ...
# 5418  Scomber scombrus (ITIS: 172414: WoRMS 127023)            not specified
# 5419  Scomber scombrus (ITIS: 172414: WoRMS 127023)            not specified
# 762   Scophthalmus rhombus (ITIS: 172749: WoRMS 127150)        not specified
# 5428  Scophthalmus rhombus (ITIS: 172749: WoRMS 127150)        not specified
# 794   Scyliorhinus canicula (ITIS: 160065: WoRMS 105814)       not specified
# 5433  Scyliorhinus canicula (ITIS: 160065: WoRMS 105814)       not specified
# 1502  Sebastes marinus (ITIS: 166781: WoRMS 151324)            not specified
# 1503  Sebastes marinus (ITIS: 166781: WoRMS 151324)            not specified
# 1504  Sebastes mentella (ITIS: 166756: WoRMS 127254)           not specified
# 4812  Sebastes mentella (ITIS: 166756: WoRMS 127254)           not specified
# 795   Solea solea (ITIS: 173002: WoRMS 127160)                 not specified
# 5439  Solea solea (ITIS: 173002: WoRMS 127160)                 not specified
# 4007  Solea vulgaris (ITIS: 173001: WoRMS 154712)              not specified
# 1505  Solea vulgaris (ITIS: 173001: WoRMS 154712)              not specified
# 1507  Solea vulgaris (ITIS: 173001: WoRMS 154712)              not specified
# 844   Somateria mollissima (ITIS: 175155: WoRMS 137074)        not specified
# 845   Somateria mollissima (ITIS: 175155: WoRMS 137074)        not specified
# 1510  Sprattus sprattus (ITIS: 161789: WoRMS 126425)           not specified
# 796   Squalus acanthias (ITIS: 160617: WoRMS 105923)           not specified
# 5448  Squalus acanthias (ITIS: 160617: WoRMS 105923)           not specified
# 763   Thunnus alalunga (ITIS: 172419: WoRMS 127026)            not specified
# 5454  Thunnus alalunga (ITIS: 172419: WoRMS 127026)            not specified
# 4320  Triglidae (ITIS: 166972: WoRMS 125598)                   not specified
# 5458  Triglidae (ITIS: 166972: WoRMS 125598)                   not specified
# 848   Uria lomvia (ITIS: 176978: WoRMS 137134)                 not specified
# 849   Ursus maritimus (ITIS: 180542: WoRMS 137085)             not specified
# 764   Zeus faber (ITIS: 166287: WoRMS 127427)                  not specified
# 5470  Zeus faber (ITIS: 166287: WoRMS 127427)                  not specified
# 850   Zoarces viviparus (ITIS: 165324: WoRMS 127123)           not specified
# 851   Zoarces viviparus (ITIS: 165324: WoRMS 127123)           not specified
#
#           S12_label
# 4236  muscle tissue
# 5474  not specified
# 1033  liver
# 4324  muscle tissue
# 5478  not specified
# 800   muscle tissue
# 5483  not specified
# 5484  not specified
# 4701  gill
# 4702  gonads
# 4703  liver
# 4704  muscle tissue
# 4241  not specified
# 803   blubber
# 4242  kidney
# 4243  liver
# 4244  muscle tissue
# 4709  gonads
# 4710  liver
# 4711  muscle tissue
# 1382  liver
# 4713  muscle tissue
# 1383  liver
# 1384  muscle tissue
# 5490  not specified
# 1385  liver
# 1386  muscle tissue
# 4338  feathers
# 4339  kidney
# 807   liver
# ...     ...
# 5418  not specified
# 5419  not specified
# 762   muscle tissue
# 5428  not specified
# 794   muscle tissue
# 5433  not specified
# 1502  liver
# 1503  muscle tissue
# 1504  liver
# 4812  muscle tissue
# 795   muscle tissue
# 5439  not specified
# 4007  liver
# 1505  muscle tissue
# 1507  not specified
# 844   body fat
# 845   liver
# 1510  muscle tissue
# 796   muscle tissue
# 5448  not specified
# 763   muscle tissue
# 5454  not specified
# 4320  muscle tissue
# 5458  not specified
# 848   liver
# 849   blubber
# 764   muscle tissue
# 5470  not specified
# 850   liver
# 851   muscle tissue
#
# [256 rows x 8 columns]

# %% [markdown]
# ### Display new biological entity combinations for S25 creation

# %%
display(param_combo[(param_combo['DTYPE']=='CF') & (param_combo['S25'].isnull())][['Species','Note','AphiaID','MATRX','S25','S25_label','TAXON','S11_label','S12_label']].drop_duplicates().sort_values(['Species','MATRX']))
# Out:
#                       Species        Note  AphiaID MATRX  S25 S25_label  \
# 804   Cepphus grylle           Bird        137130   EG    NaN  NaN
# 805   Cepphus grylle           Bird        137130   EH    NaN  NaN
# 1038  Crangon crangon          Crustacean  107552   SB    NaN  NaN
# 1418  Gadus morhua             Fish        126436   RO    NaN  NaN
# 1048  Gobius                   Fish        125988   SB    NaN  NaN
# 819   Haematopus ostralegus    Bird        147436   EG    NaN  NaN
# 822   Larus                    Bird        137043   EH    NaN  NaN
# 823   Larus argentatus         Bird        137138   EH    NaN  NaN
# 829   Myoxocephalus scorpius   Fish        127203   BB    NaN  NaN
# 1056  Mysidacea                Crustacean  149668   SB    NaN  NaN
# 834   Phoca hispida            Seal        159021   BB    NaN  NaN
# 4262  Phoca hispida            Seal        159021   KI    NaN  NaN
# 835   Phoca hispida            Seal        159021   LI    NaN  NaN
# 836   Phoca hispida            Seal        159021   MU    NaN  NaN
# 1489  Pollachius pollachius    Fish        126440   RO    NaN  NaN
# 760   Psetta maxima            Fish        127149   MU    NaN  NaN
# 4223  Raja brachyura           Fish        105882   MU    NaN  NaN
# 5387  Raja brachyura           Fish        105882   WO    NaN  NaN
# 1497  Salvelinus alpinus       Fish        127188   BB    NaN  NaN
# 846   Sterna hirundo           Bird        137162   EG    NaN  NaN
# 847   Uria aalge               Bird        137133   EG    NaN  NaN
# 751   Venerupis philippinarum  Mollusca    231750   SB    NaN  NaN
# 5463  Venerupis philippinarum  Mollusca    231750   SH    NaN  NaN
#
#                                                     TAXON      S11_label  \
# 804   Cepphus grylle (ITIS: 176985: WoRMS 137130)          eggs
# 805   Cepphus grylle (ITIS: 176985: WoRMS 137130)          eggs
# 1038  Crangon crangon (ITIS: 97118: WoRMS 107552)          not specified
# 1418  Gadus morhua (ITIS: 164712: WoRMS 126436)            eggs
# 1048  Gobius (ITIS: 171833: WoRMS 125988)                  not specified
# 819   Haematopus ostralegus (ITIS: 176469: WoRMS 147436)   eggs
# 822   Larus (ITIS: 176803: WoRMS 137043)                   eggs
# 823   Larus argentatus (ITIS: 176824: WoRMS 137138)        eggs
# 829   Myoxocephalus scorpius (ITIS: 167318: WoRMS 127203)  not specified
# 1056  Mysida (ITIS: 89855: WoRMS 149668)                   not specified
# 834   New TAXON required.                                  not specified
# 4262  New TAXON required.                                  not specified
# 835   New TAXON required.                                  not specified
# 836   New TAXON required.                                  not specified
# 1489  Pollachius pollachius (ITIS: 164728: WoRMS 126440)   eggs
# 760   Scophthalmus maximus (ITIS: 172748: WoRMS 127149)    not specified
# 4223  New TAXON required.                                  not specified
# 5387  New TAXON required.                                  not specified
# 1497  Salvelinus alpinus (ITIS: 162001: WoRMS 127188)      not specified
# 846   Sterna hirundo (ITIS: 176888: WoRMS 137162)          eggs
# 847   Uria aalge (ITIS: 176974: WoRMS 137133)              eggs
# 751   Ruditapes philippinarum (WoRMS 231750)               not specified
# 5463  Ruditapes philippinarum (WoRMS 231750)               not specified
#
#                             S12_label
# 804   not specified
# 805   egg yolk and albumen homogenate
# 1038  NaN
# 1418  not specified
# 1048  NaN
# 819   not specified
# 822   egg yolk and albumen homogenate
# 823   egg yolk and albumen homogenate
# 829   NaN
# 1056  NaN
# 834   blubber
# 4262  kidney
# 835   liver
# 836   muscle tissue
# 1489  not specified
# 760   muscle tissue
# 4223  muscle tissue
# 5387  not specified
# 1497  NaN
# 846   not specified
# 847   not specified
# 751   flesh
# 5463  shell

# %%
# Map P01 semantic component labels to vocabulary codes
param_combo = pd.merge(param_combo, S06, how='left', on='S06_label')
param_combo = pd.merge(param_combo, S07, how='left', on='S07_label')
param_combo = pd.merge(param_combo, S02, how='left', on='S02_label')
param_combo = pd.merge(param_combo, S26, how='left', on='S26_label')
param_combo = pd.merge(param_combo, S03, how='left', on='S03_label')
param_combo = pd.merge(param_combo, S04, how='left', on='S04_label')
param_combo = pd.merge(param_combo, S05, how='left', on='S05_label')

# Map P01 semantic model combinations to table combinations

param_combo = pd.merge(param_combo, P01, how='left', on=['S06','S07','S27','S02','S26','S25','S03','S04','S05'])

display(param_combo)
# Out:
#      PARGROUP                                                    PRNAM  \
# 0     -9       anthracene
# 1     -9       benzo[a]pyrene
# 2     -9       2,2',4,5,5'-pentachlorobiphenyl (CB101)
# 3     -9       2,3,3',4,4'-pentachlorobiphenyl (CB105)
# 4     -9       2,3',4,4',5-pentachlorobiphenyl (CB118)
# 5     -9       2,2',3,4,4',5'-hexachlorobiphenyl (CB138)
# 6     -9       2,2',4,4',5,5'-hexachlorobiphenyl (CB153)
# 7     -9       2,2',3,4,4',5,5'-heptachlorobiphenyl (CB180)
# 8     -9       2,4,4'-trichlorobiphenyl (CB28)
# 9     -9       2,2',5,5'-tetrachlorobiphenyl (CB52)
# 10    -9       cadmium
# 11    -9       copper
# 12    -9       DDE (p,p')
# 13    -9       DDT (o,p')
# 14    -9       DDT (p,p')
# 15    -9       fluoranthene
# 16    -9       hexachlorobenzene
# 17    -9       mercury
# 18    -9       naphthalene
# 19    -9       phenanthrene
# 20    -9       lead
# 21    -9       TDE (p,p') = DDD (p,p')
# 22    -9       zinc
# 23    -9       aluminium
# 24    -9       aluminium
# 25    -9       aluminium
# 26    -9       aluminium
# 27    -9       anthracene
# 28    -9       benzo[a]pyrene
# 29    -9       2,2',4,5,5'-pentachlorobiphenyl (CB101)
# ...   ..                                           ...
# 5665  B-BIO    length (mean or individual) (in combination with matrx)
# 5666  B-BIO    length (min) (in combination with matrx)
# 5667  B-BIO    dry weight percent
# 5668  B-BIO    dry weight percent
# 5669  B-BIO    extractable lipid percent
# 5670  B-BIO    extractable lipid percent
# 5671  B-BIO    fat weight percent
# 5672  B-BIO    fat weight percent
# 5673  B-BIO    length (max) (in combination with matrx)
# 5674  B-BIO    length (max) (in combination with matrx)
# 5675  B-BIO    length (max) (in combination with matrx)
# 5676  B-BIO    length (mean or individual) (in combination with matrx)
# 5677  B-BIO    length (mean or individual) (in combination with matrx)
# 5678  B-BIO    length (mean or individual) (in combination with matrx)
# 5679  B-BIO    length (min) (in combination with matrx)
# 5680  B-BIO    length (min) (in combination with matrx)
# 5681  B-BIO    length (min) (in combination with matrx)
# 5682  B-BIO    weight (mean or individual) (in combination with matrx)
# 5683  B-BIO    weight (mean or individual) (in combination with matrx)
# 5684  B-BIO    dry weight percent
# 5685  B-BIO    dry weight percent
# 5686  B-BIO    dry weight percent
# 5687  B-BIO    fat weight percent
# 5688  B-BIO    length (max) (in combination with matrx)
# 5689  B-BIO    length (mean or individual) (in combination with matrx)
# 5690  B-BIO    length (min) (in combination with matrx)
# 5691  B-END    % female population
# 5692  B-END    % male population
# 5693  B-END    % sterile females (IMPS 5-6, INTS 2 or above)
# 5694  O-FL     perfluorooctylsulfonate acid amide
#
#              CAS DTYPE       PARAM  MUNIT    MATRX BASIS METPT METOA  ...  \
# 0     120-12-7    CS    ANT         ug/kg  SED1000  D     -9    -9    ...
# 1     50-32-8     CS    BAP         ug/kg  SED1000  D     -9    -9    ...
# 2     37680-73-2  CS    CB101       ug/kg  SED1000  D     -9    -9    ...
# 3     32598-14-4  CS    CB105       ug/kg  SED1000  D     -9    -9    ...
# 4     31508-00-6  CS    CB118       ug/kg  SED1000  D     -9    -9    ...
# 5     35065-28-2  CS    CB138       ug/kg  SED1000  D     -9    -9    ...
# 6     35065-27-1  CS    CB153       ug/kg  SED1000  D     -9    -9    ...
# 7     35065-29-3  CS    CB180       ug/kg  SED1000  D     -9    -9    ...
# 8     7012-37-5   CS    CB28        ug/kg  SED1000  D     -9    -9    ...
# 9     35693-99-3  CS    CB52        ug/kg  SED1000  D     -9    -9    ...
# 10    7440-43-9   CS    CD          ug/kg  SED1000  D     -9    -9    ...
# 11    7440-50-8   CS    CU          ug/kg  SED1000  D     -9    -9    ...
# 12    72-55-9     CS    DDEPP       ug/kg  SED1000  D     -9    -9    ...
# 13    789-02-6    CS    DDTOP       ug/kg  SED1000  D     -9    -9    ...
# 14    50-29-3     CS    DDTPP       ug/kg  SED1000  D     -9    -9    ...
# 15    206-44-0    CS    FLU         ug/kg  SED1000  D     -9    -9    ...
# 16    118-74-1    CS    HCB         ug/kg  SED1000  D     -9    -9    ...
# 17    7439-97-6   CS    HG          ug/kg  SED1000  D     -9    -9    ...
# 18    91-20-3     CS    NAP         ug/kg  SED1000  D     -9    -9    ...
# 19    85-01-8     CS    PA          ug/kg  SED1000  D     -9    -9    ...
# 20    7439-92-1   CS    PB          ug/kg  SED1000  D     -9    -9    ...
# 21    72-54-8     CS    TDEPP       ug/kg  SED1000  D     -9    -9    ...
# 22    7440-66-6   CS    ZN          ug/kg  SED1000  D     -9    -9    ...
# 23    7429-90-5   CS    AL          %      SED20    D     -9    -9    ...
# 24    7429-90-5   CS    AL          g/kg   SED20    D     -9    -9    ...
# 25    7429-90-5   CS    AL          mg/kg  SED20    D     -9    -9    ...
# 26    7429-90-5   CS    AL          ug/kg  SED20    D     -9    -9    ...
# 27    120-12-7    CS    ANT         ug/kg  SED20    D     -9    -9    ...
# 28    50-32-8     CS    BAP         ug/kg  SED20    D     -9    -9    ...
# 29    37680-73-2  CS    CB101       ug/kg  SED20    D     -9    -9    ...
# ...          ...  ..      ...         ...    ...   ..     ..    ..    ...
# 5665  -9          CF    LNMEA       -9     SH       -9    -9    -9    ...
# 5666  -9          CF    LNMIN       -9     SH       -9    -9    -9    ...
# 5667  -9          CF    DRYWT%      -9     SB       -9    -9    -9    ...
# 5668  -9          CF    DRYWT%      -9     SB       W     -9    -9    ...
# 5669  -9          CF    EXLIP%      -9     SB       -9    -9    -9    ...
# 5670  -9          CF    EXLIP%      -9     SB       W     -9    -9    ...
# 5671  -9          CF    FATWT%      -9     SB       -9    -9    -9    ...
# 5672  -9          CF    FATWT%      -9     SB       W     -9    -9    ...
# 5673  -9          CF    LNMAX       -9     SH       -9    -9    -9    ...
# 5674  -9          CF    LNMAX       -9     WO       -9    -9    -9    ...
# 5675  -9          CF    LNMAX       -9     WO       -9    -9    -9    ...
# 5676  -9          CF    LNMEA       -9     SH       -9    -9    -9    ...
# 5677  -9          CF    LNMEA       -9     WO       -9    -9    -9    ...
# 5678  -9          CF    LNMEA       -9     WO       -9    -9    -9    ...
# 5679  -9          CF    LNMIN       -9     SH       -9    -9    -9    ...
# 5680  -9          CF    LNMIN       -9     WO       -9    -9    -9    ...
# 5681  -9          CF    LNMIN       -9     WO       -9    -9    -9    ...
# 5682  -9          CF    WTMEA       -9     EX       -9    -9    -9    ...
# 5683  -9          CF    WTMEA       -9     SB       -9    -9    -9    ...
# 5684  -9          CF    DRYWT%      -9     MU       -9    -9    -9    ...
# 5685  -9          CF    DRYWT%      -9     MU       W     -9    -9    ...
# 5686  -9          CF    DRYWT%      -9     TM       W     -9    -9    ...
# 5687  -9          CF    FATWT%      -9     TM       W     -9    -9    ...
# 5688  -9          CF    LNMAX       -9     WO       -9    -9    -9    ...
# 5689  -9          CF    LNMEA       -9     WO       -9    -9    -9    ...
# 5690  -9          CF    LNMIN       -9     WO       -9    -9    -9    ...
# 5691  -9          CF    %FEMALEPOP  -9     SB       W     -9    -9    ...
# 5692  -9          CF    %MALEPOP    -9     SB       W     -9    -9    ...
# 5693  -9          CF    %STERF      -9     SB       W     -9    -9    ...
# 5694  NV          CF    PFOSA       -9     SB       W     -9    -9    ...
#
#                                                                           S25_label  \
# 0     not applicable
# 1     not applicable
# 2     not applicable
# 3     not applicable
# 4     not applicable
# 5     not applicable
# 6     not applicable
# 7     not applicable
# 8     not applicable
# 9     not applicable
# 10    not applicable
# 11    not applicable
# 12    not applicable
# 13    not applicable
# 14    not applicable
# 15    not applicable
# 16    not applicable
# 17    not applicable
# 18    not applicable
# 19    not applicable
# 20    not applicable
# 21    not applicable
# 22    not applicable
# 23    not applicable
# 24    not applicable
# 25    not applicable
# 26    not applicable
# 27    not applicable
# 28    not applicable
# 29    not applicable
# ...              ...
# 5665  Mya truncata (ITIS: 81694: WoRMS 140431) [Subcomponent: shell]
# 5666  Mya truncata (ITIS: 81694: WoRMS 140431) [Subcomponent: shell]
# 5667  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5668  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5669  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5670  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5671  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5672  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5673  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: shell]
# 5674  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5675  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Stage: larvae]
# 5676  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: shell]
# 5677  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5678  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Stage: larvae]
# 5679  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: shell]
# 5680  Mytilus edulis (ITIS: 79454: WoRMS 140480)
# 5681  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Stage: larvae]
# 5682  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: shell]
# 5683  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
# 5684  Nephrops norvegicus (ITIS: 97317: WoRMS 107254) [Subcomponent: muscle tissue]
# 5685  Nephrops norvegicus (ITIS: 97317: WoRMS 107254) [Subcomponent: muscle tissue]
# 5686  Nephrops norvegicus (ITIS: 97317: WoRMS 107254) [Subcomponent: muscle tissue]
# 5687  Nephrops norvegicus (ITIS: 97317: WoRMS 107254) [Subcomponent: muscle tissue]
# 5688  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5689  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5690  Nephrops norvegicus (ITIS: 97317: WoRMS 107254)
# 5691  Nucella lapillus (ITIS: 73297: WoRMS 140403) [Subcomponent: flesh]
# 5692  Nucella lapillus (ITIS: 73297: WoRMS 140403) [Subcomponent: flesh]
# 5693  Nucella lapillus (ITIS: 73297: WoRMS 140403) [Subcomponent: flesh]
# 5694  Mytilus edulis (ITIS: 79454: WoRMS 140480) [Subcomponent: flesh]
#
#            S06       S07   S02       S26    S03    S04      S05       P01  \
# 0     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000127
# 1     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000012
# 2     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000065
# 3     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000150
# 4     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000122
# 5     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000151
# 6     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000047
# 7     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000048
# 8     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000106
# 9     S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000028
# 10    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  NaN
# 11    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  NaN
# 12    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000029
# 13    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000152
# 14    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000013
# 15    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000123
# 16    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000050
# 17    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  NaN
# 18    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000014
# 19    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000066
# 20    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  NaN
# 21    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  IC000015
# 22    S0600045  S0700006  S041  MAT01975  S0316  S0421  S050003  NaN
# 23    S0600018  S0700006  S041  MAT01977  S0316  S0421  S050003  NaN
# 24    S0600045  S0700006  S041  MAT01977  S0316  S0421  S050003  NaN
# 25    S0600045  S0700006  S041  MAT01977  S0316  S0421  S050003  NaN
# 26    S0600045  S0700006  S041  MAT01977  S0316  S0421  S050003  NaN
# 27    S0600045  S0700006  S041  MAT01977  S0316  S0421  S050003  IC000124
# 28    S0600045  S0700006  S041  MAT01977  S0316  S0421  S050003  IC000030
# 29    S0600045  S0700006  S041  MAT01977  S0316  S0421  S050003  IC000089
# ...        ...       ...   ...       ...    ...    ...      ...       ...
# 5665  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5666  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5667  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5668  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5669  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5670  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5671  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5672  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5673  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5674  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5675  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5676  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5677  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5678  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5679  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5680  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5681  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5682  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5683  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5684  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5685  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5686  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5687  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5688  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5689  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5690  NaN       S0700006  NaN   MAT01963  S0316  S0421  S050003  NaN
# 5691  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5692  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5693  NaN       S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
# 5694  S0600045  S0700006  S055  MAT01963  S0316  S0421  S050003  NaN
#
#                                                                                                                   P01_label
# 0     Concentration of anthracene {CAS 120-12-7} per unit dry weight of sediment <1000um
# 1     Concentration of benzo(a)pyrene {CAS 50-32-8} per unit dry weight of sediment <1000um
# 2     Concentration of 2,2',4,5,5'-pentachlorobiphenyl {PCB101 CAS 37680-73-2} per unit dry weight of sediment <1000um
# 3     Concentration of 2,3,3',4,4'-pentachlorobiphenyl {PCB105 CAS 32598-14-4} per unit dry weight of sediment <1000um
# 4     Concentration of 2,3',4,4',5-pentachlorobiphenyl {PCB118 CAS 31508-00-6} per unit dry weight of sediment <1000um
# 5     Concentration of 2,2',3,4,4',5'-hexachlorobiphenyl {PCB138 CAS 35065-28-2} per unit dry weight of sediment <1000um
# 6     Concentration of 2,2',4,4',5,5'-hexachlorobiphenyl {PCB153 CAS 35065-27-1} per unit dry weight of sediment <1000um
# 7     Concentration of 2,2',3,4,4',5,5'-heptachlorobiphenyl {PCB180 CAS 35065-29-3} per unit dry weight of sediment <1000um
# 8     Concentration of 2,4,4'-trichlorobiphenyl {PCB28 CAS 7012-37-5} per unit dry weight of sediment <1000um
# 9     Concentration of 2,2',5,5'-tetrachlorobiphenyl {PCB52 CAS 35693-99-3} per unit dry weight of sediment <1000um
# 10    NaN
# 11    NaN
# 12    Concentration of 4,4'-dichlorodiphenyldichloroethylene {p,p'-DDE CAS 72-55-9} per unit dry weight of sediment <1000um
# 13    Concentration of 2,4'-dichlorodiphenyltrichloroethane {o,p'-DDT CAS 789-02-6} per unit dry weight of sediment <1000um
# 14    Concentration of 4,4'-dichlorodiphenyltrichloroethane {p,p'-DDT CAS 50-29-3} per unit dry weight of sediment <1000um
# 15    Concentration of fluoranthene {CAS 206-44-0} per unit dry weight of sediment <1000um
# 16    Concentration of hexachlorobenzene {HCB CAS 118-74-1} per unit dry weight of sediment <1000um
# 17    NaN
# 18    Concentration of naphthalene {CAS 91-20-3} per unit dry weight of sediment <1000um
# 19    Concentration of phenanthrene {CAS 85-01-8} per unit dry weight of sediment <1000um
# 20    NaN
# 21    Concentration of 4,4'-dichlorodiphenyldichloroethane {p,p'-DDD CAS 72-54-8} per unit dry weight of sediment <1000um
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    Concentration of anthracene {CAS 120-12-7} per unit dry weight of sediment <20um
# 28    Concentration of benzo(a)pyrene {CAS 50-32-8} per unit dry weight of sediment <20um
# 29    Concentration of 2,2',4,5,5'-pentachlorobiphenyl {PCB101 CAS 37680-73-2} per unit dry weight of sediment <20um
# ...                                                                                                              ...
# 5665  NaN
# 5666  NaN
# 5667  NaN
# 5668  NaN
# 5669  NaN
# 5670  NaN
# 5671  NaN
# 5672  NaN
# 5673  NaN
# 5674  NaN
# 5675  NaN
# 5676  NaN
# 5677  NaN
# 5678  NaN
# 5679  NaN
# 5680  NaN
# 5681  NaN
# 5682  NaN
# 5683  NaN
# 5684  NaN
# 5685  NaN
# 5686  NaN
# 5687  NaN
# 5688  NaN
# 5689  NaN
# 5690  NaN
# 5691  NaN
# 5692  NaN
# 5693  NaN
# 5694  NaN
#
# [5695 rows x 51 columns]

# %%
# Replaces any problematic text characters from the NVS imported into the DataFrame
# that will cause issues when writing the output to file.
param_combo.replace(u'\xa0',u' ', regex=True, inplace=True)
param_combo.replace(u'\u2019',u"'", regex=True, inplace=True)

# Reorder columns for output
param_combo = param_combo[['PARGROUP','PRNAM','CAS','DTYPE','PARAM','MUNIT','MATRX','BASIS','METPT','METOA','Note','AphiaID','Species',
                          'P01_Code','P01','P01_label','S06_label','S07_label','S27_label','S02_label','S26_label','S25_label',
                          'TAXON','S09_label','S10_label','S11_label','S12_label','S13_label','S14_label','S15_label',
                          'S06','S07','S27','S02','S26','S25','S09','S10','S11','S12','S13','S14','S15']]

print("Total combinations in file = %s" % (len(param_combo)))
# Out:
# Total combinations in file = 5695

# %% [markdown]
# # Save the results of the ICES to NVS semantic model mapping to file.

# %%
# Save complete DataFrame
full_results = os.path.join(results,'complete_output.csv')
param_combo.to_csv(full_results, index=False)
print("Full results set saved to: %s" % full_results)
# Out:
# Full results set saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\complete_output.csv

# %%
x=len(param_combo[param_combo['P01_Code']!='-9'])
y=len(param_combo[(param_combo['P01_Code']=='-9') & (param_combo['P01'].notnull())])
z=len(param_combo[(param_combo['P01_Code']=='-9') & (param_combo['P01'].isnull())])

# Split out those combinations that have already been mapped to P01 in the parameter set
previous_P01 = os.path.join(results,'previous_P01.csv')
param_combo[param_combo['P01_Code']!='-9'].to_csv(previous_P01, index=False)
print("Subset of previously mapped P01 terms saved to: %s" % full_results)

# Retain those combinations that have not yet been mapped to P01
mapped_P01 = os.path.join(results,'mapped_P01.csv')
param_combo[(param_combo['P01_Code']=='-9') & (param_combo['P01'].notnull())].to_csv(mapped_P01, index=False)
print("Subset of newly mapped P01 terms saved to: %s" % mapped_P01)

# Retain those combinations that have not yet been mapped to P01
new_P01 = os.path.join(results,'new_P01.csv')
param_combo[(param_combo['P01_Code']=='-9') & (param_combo['P01'].isnull())].to_csv(new_P01, index=False)
print("Subset of possible P01 terms for creation saved to: %s" % new_P01)
    
# Create summary information
summary = pd.DataFrame([["Processing started:" , (start.strftime('%Y-%m-%d %H:%M:%S'))],
["Processing finished:" , datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')],
["" , ""],
["Rows input:", len(inputs)],
["Rows output:" , len(param_combo)],
["Rows with P01 provided:" , x],
["Rows successfully mapped:" , y],
["Rows unable to be mapped:" , z],
["Because:", ""],
["    Non-chemical PARAMs to be mapped:" , len(alt_mapping)],
["    New chemical substances (S27) for mapping:" , len(S27new)],
["    New matrix terms (S26) for creation:" , len(S26new)],
["    New biological entities (S25) for creation:" , len(S25new)],
["    Taxa discrepancies to be resolved:" , len(taxa_discrepancy)]])




print("\nProcess results all saved to directory: %s" % results)
display(summary)

if len(param_combo)!= len(inputs):
    print("Check for duplicated results as number of rows out do not match number of rows in original file")
# Out:
# Subset of previously mapped P01 terms saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\complete_output.csv
# Subset of newly mapped P01 terms saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\mapped_P01.csv
# Subset of possible P01 terms for creation saved to: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results\new_P01.csv
#
# Process results all saved to directory: C:\Users\rthomas\Documents\GitHub\ICES2NVS_semantic_map_ext\example\results
#                                                   0                    1
# 0   Processing started:                              2021-06-12 23:27:44
# 1   Processing finished:                             2021-06-12 23:28:01
# 2
# 3   Rows input:                                      5439
# 4   Rows output:                                     5695
# 5   Rows with P01 provided:                          563
# 6   Rows successfully mapped:                        3305
# 7   Rows unable to be mapped:                        1827
# 8   Because:
# 9       Non-chemical PARAMs to be mapped:            28
# 10      New chemical substances (S27) for mapping:   49
# 11      New matrix terms (S26) for creation:         5
# 12      New biological entities (S25) for creation:  23
# 13      Taxa discrepancies to be resolved:           9
# Check for duplicated results as number of rows out do not match number of rows in original file
